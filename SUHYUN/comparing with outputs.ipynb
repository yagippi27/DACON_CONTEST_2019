# %%
import pandas as pd
from SMAPE import *
import os
from os import listdir
from os.path import isfile, join

# %%
os.getcwd()
# Out:
# 'E:\\DACON_CONTEST_2019\\SUHYUN'

# %%
os.chdir('E:\\DACON_CONTEST_2019\\SUHYUN\\output\\test')

# %%
filepath = os.getcwd()

# %%
# 색인: 파일이름
files = [f for f in listdir(filepath) if isfile(join(filepath, f))]
files
# Out:
# ['ARIMA.csv',
#  'avg_per_hour_ARIMA.csv',
#  'NA_DACON_method_ARIMA.csv',
#  'NA_DACON_method_r48_mean_ARIMA.csv',
#  'NA_DACON_method_r48_med_ARIMA.csv',
#  'r48_med_ARIMA.csv',
#  'r720_mean_ARIMA_itertools(0,3).csv',
#  'Score.csv']

# %% [markdown]
# # 1. ARIMA

# %%
ARIMA = pd.read_csv("ARIMA.csv")
ARIMA.head()
# Out:
#   meter_id  X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  \
# 0       X5      6.799337      6.608444      6.502226      6.443249
# 1       X7      1.308541      1.318726      1.327311      1.334546
# 2      X10      2.245586      2.397961      2.522193      2.623480
# 3      X16      3.314387      3.423443      3.510585      3.580217
# 4      X18      2.495489      2.500711      2.504911      2.508287
#
#    X2018_7_1_5h  X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  X2018_7_1_9h  ...  \
# 0      6.410628      6.392713      6.383001      6.377866      6.375284  ...
# 1      1.340644      1.345784      1.350116      1.353767      1.356845  ...
# 2      2.706060      2.773387      2.828279      2.873033      2.909521  ...
# 3      3.635857      3.680316      3.715842      3.744229      3.766912  ...
# 4      2.510998      2.513173      2.514916      2.516309      2.517421  ...
#
#    X2018_7_6_d  X2018_7_7_d  X2018_7_8_d  X2018_7_9_d  X2018_7_10_d  \
# ...

# %%
ARIMA.describe()
# Out:
#        X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  X2018_7_1_5h  \
# count    200.000000    200.000000    200.000000    200.000000    200.000000
# mean       0.771216      0.758193      0.751534      0.747709      0.745339
# std        2.127130      2.037289      1.972492      1.925341      1.890749
# min        0.006011      0.006016      0.006016      0.006017      0.006017
# 25%        0.252858      0.248951      0.248714      0.248340      0.246632
# 50%        0.344808      0.336831      0.337029      0.333529      0.326990
# 75%        0.488715      0.467004      0.465225      0.457112      0.458127
# max       20.458173     20.194542     20.027700     19.922411     19.856268
#
#        X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  X2018_7_1_9h  X2018_7_1_10h  \
# count    200.000000    200.000000    200.000000    200.000000     200.000000
# mean       0.743808      0.742802      0.742145      0.741728       0.741479
# ...

# %% [markdown]
# # 2. avg_per_hour_ARIMA

# %%
avg_per_hour_ARIMA = pd.read_csv("avg_per_hour_ARIMA.csv")
avg_per_hour_ARIMA.head()
# Out:
#   meter_id  X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  \
# 0       X5      6.853865      6.662421      6.535229      6.450732
# 1       X7      1.258811      1.275497      1.289773      1.301985
# 2      X10      2.166754      2.297002      2.408626      2.504290
# 3      X16      3.294517      3.381436      3.454943      3.517108
# 4      X18      2.500810      2.510078      2.517351      2.523060
#
#    X2018_7_1_5h  X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  X2018_7_1_9h  ...  \
# 0      6.394607      6.357335      6.332590      6.316171      6.305283  ...
# 1      1.312433      1.321371      1.329018      1.335560      1.341157  ...
# 2      2.586275      2.656537      2.716753      2.768359      2.812586  ...
# 3      3.569681      3.614141      3.651741      3.683540      3.710432  ...
# 4      2.527539      2.531054      2.533812      2.535976      2.537673  ...
#
#    X2018_7_6_d  X2018_7_7_d  X2018_7_8_d  X2018_7_9_d  X2018_7_10_d  \
# ...

# %%
avg_per_hour_ARIMA.describe()
# Out:
#        X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  X2018_7_1_5h  \
# count    200.000000    200.000000    200.000000    200.000000    200.000000
# mean       0.777086      0.762977      0.755046      0.750398      0.747559
# std        2.117934      2.025741      1.955765      1.902275      1.861202
# min        0.006012      0.006016      0.006016      0.006016      0.006016
# 25%        0.268305      0.273686      0.272978      0.268614      0.266115
# 50%        0.358706      0.348385      0.350253      0.345286      0.338344
# 75%        0.490668      0.467833      0.467525      0.466306      0.467110
# max       20.367642     19.973079     19.665623     19.426038     19.239337
#
#        X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  X2018_7_1_9h  X2018_7_1_10h  \
# count    200.000000    200.000000    200.000000    200.000000     200.000000
# mean       0.745761      0.744587      0.743802      0.743268       0.742900
# ...

# %% [markdown]
# # 3. NA_DACON_method_ARIMA

# %%
NA_DACON_method_ARIMA = pd.read_csv("NA_DACON_method_ARIMA.csv")
NA_DACON_method_ARIMA.head()
# Out:
#   meter_id  X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  \
# 0       X5      6.799336      6.608443      6.502225      6.443248
# 1       X7      1.308541      1.318726      1.327311      1.334546
# 2      X10      2.245585      2.397961      2.522193      2.623480
# 3      X16      3.314387      3.423443      3.510585      3.580217
# 4      X18      2.495490      2.500712      2.504913      2.508289
#
#    X2018_7_1_5h  X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  X2018_7_1_9h  ...  \
# 0      6.410627      6.392711      6.382999      6.377864      6.375283  ...
# 1      1.340644      1.345784      1.350116      1.353767      1.356845  ...
# 2      2.706059      2.773387      2.828279      2.873033      2.909521  ...
# 3      3.635857      3.680316      3.715842      3.744229      3.766913  ...
# 4      2.511000      2.513175      2.514918      2.516311      2.517423  ...
#
#    X2018_7_6_d  X2018_7_7_d  X2018_7_8_d  X2018_7_9_d  X2018_7_10_d  \
# ...

# %%
NA_DACON_method_ARIMA.describe()
# Out:
#        X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  X2018_7_1_5h  \
# count    200.000000    200.000000    200.000000    200.000000    200.000000
# mean       0.788104      0.771782      0.762276      0.756630      0.753233
# std        2.126054      2.035863      1.971133      1.924102      1.889586
# min        0.006011      0.006016      0.006016      0.006017      0.006017
# 25%        0.257742      0.255941      0.254991      0.252416      0.254102
# 50%        0.364849      0.348123      0.347069      0.335396      0.331691
# 75%        0.514644      0.511436      0.487315      0.475232      0.470729
# max       20.458173     20.194541     20.027699     19.922411     19.856267
#
#        X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  X2018_7_1_9h  X2018_7_1_10h  \
# count    200.000000    200.000000    200.000000    200.000000     200.000000
# mean       0.751184      0.749960      0.749255      0.748880       0.748718
# ...

# %% [markdown]
# # 4. NA_DACON_method_r48_mean_ARIMA

# %%
NA_DACON_method_r48_mean_ARIMA = pd.read_csv("NA_DACON_method_r48_mean_ARIMA.csv")
NA_DACON_method_r48_mean_ARIMA.head()
# Out:
#   meter_id  X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  \
# 0       X5      6.412657      6.420777      6.425877      6.429190
# 1       X7      2.132067      2.131349      2.130759      2.130279
# 2      X10      4.718981      4.716739      4.715346      4.714612
# 3      X16      5.285298      5.288478      5.290728      5.292478
# 4      X18      2.638968      2.638332      2.637785      2.637319
#
#    X2018_7_1_5h  X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  X2018_7_1_9h  ...  \
# 0      6.431443      6.433070      6.434325      6.435360      6.436266  ...
# 1      2.129891      2.129584      2.129343      2.129160      2.129026  ...
# 2      4.714392      4.714571      4.715061      4.715792      4.716711  ...
# 3      5.293957      5.295290      5.296545      5.297757      5.298946  ...
# 4      2.636924      2.636591      2.636312      2.636082      2.635894  ...
#
#    X2018_7_6_d  X2018_7_7_d  X2018_7_8_d  X2018_7_9_d  X2018_7_10_d  \
# ...

# %%
ARIMA.describe()
# Out:
#        X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  X2018_7_1_5h  \
# count    200.000000    200.000000    200.000000    200.000000    200.000000
# mean       0.771216      0.758193      0.751534      0.747709      0.745339
# std        2.127130      2.037289      1.972492      1.925341      1.890749
# min        0.006011      0.006016      0.006016      0.006017      0.006017
# 25%        0.252858      0.248951      0.248714      0.248340      0.246632
# 50%        0.344808      0.336831      0.337029      0.333529      0.326990
# 75%        0.488715      0.467004      0.465225      0.457112      0.458127
# max       20.458173     20.194542     20.027700     19.922411     19.856268
#
#        X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  X2018_7_1_9h  X2018_7_1_10h  \
# count    200.000000    200.000000    200.000000    200.000000     200.000000
# mean       0.743808      0.742802      0.742145      0.741728       0.741479
# ...

# %% [markdown]
# # 5. NA_DACON_method_r48_med_ARIMA

# %%
NA_DACON_method_r48_med_ARIMA = pd.read_csv("NA_DACON_method_r48_med_ARIMA.csv")
NA_DACON_method_r48_med_ARIMA.head()
# Out:
#   meter_id  X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  \
# 0       X5      6.414162      6.415860      6.416758      6.417495
# 1       X7      1.485958      1.484842      1.484238      1.483917
# 2      X10      3.226025      3.226370      3.227080      3.227890
# 3      X16      5.026338      5.027509      5.028437      5.029315
# 4      X18      2.578535      2.578574      2.578614      2.578656
#
#    X2018_7_1_5h  X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  X2018_7_1_9h  ...  \
# 0      6.418199      6.418896      6.419592      6.420288      6.420984  ...
# 1      1.483752      1.483673      1.483642      1.483637      1.483647  ...
# 2      3.228728      3.229574      3.230422      3.231271      3.232120  ...
# 3      5.030183      5.031048      5.031913      5.032777      5.033642  ...
# 4      2.578700      2.578744      2.578789      2.578835      2.578881  ...
#
#    X2018_7_6_d  X2018_7_7_d  X2018_7_8_d  X2018_7_9_d  X2018_7_10_d  \
# ...

# %%
NA_DACON_method_r48_med_ARIMA.describe()
# Out:
#        X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  X2018_7_1_5h  \
# count    200.000000    200.000000    200.000000    200.000000    200.000000
# mean       0.666956      0.667678      0.667895      0.667956      0.667959
# std        1.868859      1.868654      1.868566      1.868611      1.868723
# min        0.003831      0.004756      0.005673      0.006000      0.006000
# 25%        0.193533      0.193619      0.193636      0.193638      0.193637
# 50%        0.276543      0.277222      0.277315      0.277145      0.276243
# 75%        0.390158      0.391078      0.391212      0.391270      0.391300
# max       19.285031     19.287461     19.291038     19.295069     19.299279
#
#        X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  X2018_7_1_9h  X2018_7_1_10h  \
# count    200.000000    200.000000    200.000000    200.000000     200.000000
# mean       0.667935      0.667897      0.667848      0.667795       0.667738
# ...

# %% [markdown]
# # 6. r48_med_ARIMA

# %%
r48_med_ARIMA = pd.read_csv("r48_med_ARIMA.csv")
r48_med_ARIMA.head()
# Out:
#   meter_id  X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  \
# 0       X5      6.414162      6.415860      6.416758      6.417495
# 1       X7      1.485958      1.484842      1.484238      1.483917
# 2      X10      3.226025      3.226370      3.227080      3.227890
# 3      X16      5.026338      5.027509      5.028437      5.029315
# 4      X18      2.578535      2.578574      2.578614      2.578656
#
#    X2018_7_1_5h  X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  X2018_7_1_9h  ...  \
# 0      6.418199      6.418896      6.419592      6.420288      6.420984  ...
# 1      1.483752      1.483673      1.483642      1.483637      1.483647  ...
# 2      3.228728      3.229574      3.230422      3.231271      3.232120  ...
# 3      5.030182      5.031048      5.031912      5.032777      5.033642  ...
# 4      2.578700      2.578744      2.578789      2.578835      2.578881  ...
#
#    X2018_7_6_d  X2018_7_7_d  X2018_7_8_d  X2018_7_9_d  X2018_7_10_d  \
# ...

# %%
ARIMA.describe()
# Out:
#        X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  X2018_7_1_5h  \
# count    200.000000    200.000000    200.000000    200.000000    200.000000
# mean       0.771216      0.758193      0.751534      0.747709      0.745339
# std        2.127130      2.037289      1.972492      1.925341      1.890749
# min        0.006011      0.006016      0.006016      0.006017      0.006017
# 25%        0.252858      0.248951      0.248714      0.248340      0.246632
# 50%        0.344808      0.336831      0.337029      0.333529      0.326990
# 75%        0.488715      0.467004      0.465225      0.457112      0.458127
# max       20.458173     20.194542     20.027700     19.922411     19.856268
#
#        X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  X2018_7_1_9h  X2018_7_1_10h  \
# count    200.000000    200.000000    200.000000    200.000000     200.000000
# mean       0.743808      0.742802      0.742145      0.741728       0.741479
# ...

# %% [markdown]
# # 7. r720_mean_ARIMA_itertools

# %%
r720_mean_ARIMA_itertools3 = pd.read_csv("r720_mean_ARIMA_itertools3.csv")
r720_mean_ARIMA_itertools3.head()
# Out:
#   meter_id  X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  \
# 0       X5      6.011721      6.012731      6.013415      6.014006
# 1       X7      1.497941      1.496024      1.493124      1.489561
# 2      X10      3.361354      3.361715      3.362147      3.362707
# 3      X16      4.294140      4.294769      4.295303      4.295819
# 4      X18      2.545643      2.545583      2.545530      2.545484
#
#    X2018_7_1_5h  X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  X2018_7_1_9h  ...  \
# 0      6.014526      6.015015      6.015486      6.015947      6.016404  ...
# 1      1.485671      1.481733      1.477935      1.474375      1.471073  ...
# 2      3.363326      3.364007      3.364724      3.365473      3.366243  ...
# 3      4.296368      4.296952      4.297552      4.298146      4.298729  ...
# 4      2.545445      2.545414      2.545390      2.545374      2.545365  ...
#
#    X2018_7_6_d  X2018_7_7_d  X2018_7_8_d  X2018_7_9_d  X2018_7_10_d  \
# ...

# %%
r720_mean_ARIMA_itertools3.describe()
# Out:
#        X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  X2018_7_1_5h  \
# count    200.000000    200.000000    200.000000    200.000000    200.000000
# mean       0.690470      0.690542      0.690533      0.690478      0.690430
# std        1.481215      1.481225      1.480911      1.480378      1.479649
# min        0.005887      0.005887      0.005887      0.005887      0.005887
# 25%        0.249875      0.249790      0.249728      0.249684      0.249667
# 50%        0.322389      0.322294      0.322310      0.322404      0.322389
# 75%        0.425965      0.426181      0.426359      0.426506      0.426628
# max       12.637886     12.648015     12.655267     12.659188     12.659520
#
#        X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  X2018_7_1_9h  X2018_7_1_10h  \
# count    200.000000    200.000000    200.000000    200.000000     200.000000
# mean       0.690376      0.690286      0.690195      0.690137       0.690087
# ...

# %% [markdown]
# # SMAPE 적용
# print(smape_fast())

# %%
print(smape_fast(ARIMA,avg_per_hour_ARIMA))
print(smape_fast(ARIMA,NA_DACON_method_ARIMA))
print(smape_fast(ARIMA,NA_DACON_method_r48_mean_ARIMA))
print(smape_fast(ARIMA,NA_DACON_method_r48_med_ARIMA))
print(smape_fast(ARIMA,r48_med_ARIMA))
print(smape_fast(ARIMA,r720_mean_ARIMA_itertools3))
print(smape_fast(avg_per_hour_ARIMA,ARIMA))
print(smape_fast(avg_per_hour_ARIMA,NA_DACON_method_ARIMA))
print(smape_fast(avg_per_hour_ARIMA,NA_DACON_method_r48_mean_ARIMA))
print(smape_fast(avg_per_hour_ARIMA,NA_DACON_method_r48_med_ARIMA))
print(smape_fast(avg_per_hour_ARIMA,r48_med_ARIMA))
print(smape_fast(avg_per_hour_ARIMA,r720_mean_ARIMA_itertools3))
print(smape_fast(NA_DACON_method_ARIMA,ARIMA))
print(smape_fast(NA_DACON_method_ARIMA,avg_per_hour_ARIMA))
print(smape_fast(NA_DACON_method_ARIMA,NA_DACON_method_r48_mean_ARIMA))
print(smape_fast(NA_DACON_method_ARIMA,NA_DACON_method_r48_med_ARIMA))
print(smape_fast(NA_DACON_method_ARIMA,r48_med_ARIMA))
print(smape_fast(NA_DACON_method_ARIMA,r720_mean_ARIMA_itertools3))
print(smape_fast(NA_DACON_method_r48_mean_ARIMA,ARIMA))
print(smape_fast(NA_DACON_method_r48_mean_ARIMA,avg_per_hour_ARIMA))
print(smape_fast(NA_DACON_method_r48_mean_ARIMA,NA_DACON_method_ARIMA))
print(smape_fast(NA_DACON_method_r48_mean_ARIMA,NA_DACON_method_r48_med_ARIMA))
print(smape_fast(NA_DACON_method_r48_mean_ARIMA,r48_med_ARIMA))
print(smape_fast(NA_DACON_method_r48_mean_ARIMA,r720_mean_ARIMA_itertools3))
print(smape_fast(NA_DACON_method_r48_med_ARIMA,ARIMA))
print(smape_fast(NA_DACON_method_r48_med_ARIMA,avg_per_hour_ARIMA))
print(smape_fast(NA_DACON_method_r48_med_ARIMA,NA_DACON_method_ARIMA))
print(smape_fast(NA_DACON_method_r48_med_ARIMA,NA_DACON_method_r48_mean_ARIMA))
print(smape_fast(NA_DACON_method_r48_med_ARIMA,r48_med_ARIMA))
print(smape_fast(NA_DACON_method_r48_med_ARIMA,r720_mean_ARIMA_itertools3))
print(smape_fast(r48_med_ARIMA,ARIMA))
print(smape_fast(r48_med_ARIMA,avg_per_hour_ARIMA))
print(smape_fast(r48_med_ARIMA,NA_DACON_method_ARIMA))
print(smape_fast(r48_med_ARIMA,NA_DACON_method_r48_mean_ARIMA))
print(smape_fast(r48_med_ARIMA,NA_DACON_method_r48_med_ARIMA))
print(smape_fast(r48_med_ARIMA,r720_mean_ARIMA_itertools3))
print(smape_fast(r720_mean_ARIMA_itertools3,ARIMA))
print(smape_fast(r720_mean_ARIMA_itertools3,avg_per_hour_ARIMA))
print(smape_fast(r720_mean_ARIMA_itertools3,NA_DACON_method_ARIMA))
print(smape_fast(r720_mean_ARIMA_itertools3,NA_DACON_method_r48_mean_ARIMA))
print(smape_fast(r720_mean_ARIMA_itertools3,NA_DACON_method_r48_med_ARIMA))
print(smape_fast(r720_mean_ARIMA_itertools3,r48_med_ARIMA))
# Out:
# 9.679389994147028
# 2.6274296263450934
# 18.901564939960988
# 29.505643046673978
# 28.27929830570257
# 15.856432984792114
# 9.679389994147028
# 10.415777220405793
# 20.539805229296928
# 32.51918139331679
# 31.443231701056714
# 13.918047836071723
# 2.6274296263450934
# 10.415777220405793
# 18.31339109720739
# 29.18122777211097
# 28.943637478086465
# 16.582634715324392
# 18.901564939960988
# 20.539805229296928
# 18.31339109720739
# 26.034952301303775
# 27.671978245740974
# 7.009284503952741
# 29.505643046673978
# 32.51918139331679
# 29.18122777211097
# 26.034952301303775
# 9.868067185651885
# 22.787255547767483
# 28.27929830570257
# 31.443231701056714
# 28.943637478086465
# 27.671978245740974
# 9.868067185651885
# 10.531571671415623
# 15.856432984792114
# 13.918047836071723
# 16.582634715324392
# 7.009284503952741
# 22.787255547767483
# 10.531571671415623
