# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
os.getcwd()
# Out:
# 'D:\\mywork\\DACON_CONTEST_2019'

# %%
os.chdir('D:\\mywork\\DACON_CONTEST_2019')

# %%
df = pd.read_csv('.\\SOOMIN\\data\\TEST_DHweightDaconArima_NAFilled.csv')
df['Time'] = pd.to_datetime(df['Time']) 
df = df.set_index('Time')

# %%
df
# Out:
#                           X26   X303   X241   X435   X402   X352   X305  \
# Time
# 2018-04-17 00:00:00  1.088616  0.444  0.247  0.342  0.203  0.237  0.368
# 2018-04-17 01:00:00  1.187378  0.385  0.168  0.326  0.201  0.254  0.286
# 2018-04-17 02:00:00  1.260810  0.363  0.185  0.321  0.174  0.130  0.234
# 2018-04-17 03:00:00  1.315409  0.273  0.196  0.295  0.182  0.097  0.278
# 2018-04-17 04:00:00  1.356003  0.341  0.249  0.314  0.198  0.101  0.186
# 2018-04-17 05:00:00  1.386187  0.330  0.343  0.353  0.196  0.097  0.276
# 2018-04-17 06:00:00  1.408628  0.401  0.381  0.383  0.287  0.128  0.427
# 2018-04-17 07:00:00  1.425314  0.485  0.411  0.299  0.412  0.094  0.758
# 2018-04-17 08:00:00  1.437721  0.601  0.368  0.321  0.501  0.098  0.400
# 2018-04-17 09:00:00  1.446945  0.218  0.289  0.379  0.222  0.106  0.293
# 2018-04-17 10:00:00  1.453803  0.274  0.197  0.319  0.199  0.164  0.294
# 2018-04-17 11:00:00  1.458903  0.202  0.168  0.303  0.164  0.149  0.280
# ...

# %%
plt.figure(figsize=(12,5))
df['X26'].plot()
df1 = df['2018-04-17':]*1000 # kWh -> Wh로 변환, 4월 17일 기점이 90퍼센트의 값들이 들어있는 곳.

# %%
df1.head()
# Out:
#                              X26   X303   X241   X435   X402   X352   X305  \
# Time
# 2018-04-17 00:00:00  1088.615532  444.0  247.0  342.0  203.0  237.0  368.0
# 2018-04-17 01:00:00  1187.378239  385.0  168.0  326.0  201.0  254.0  286.0
# 2018-04-17 02:00:00  1260.810311  363.0  185.0  321.0  174.0  130.0  234.0
# 2018-04-17 03:00:00  1315.408542  273.0  196.0  295.0  182.0   97.0  278.0
# 2018-04-17 04:00:00  1356.003432  341.0  249.0  314.0  198.0  101.0  186.0
#
#                       X350  X326   X299  ...   X283   X329   X223   X266  \
# Time                                     ...
# 2018-04-17 00:00:00  254.0  25.0  187.0  ...  333.0  324.0  322.0  472.0
# 2018-04-17 01:00:00  239.0  25.0  175.0  ...  226.0  312.0  168.0  156.0
# 2018-04-17 02:00:00  323.0  26.0  187.0  ...  104.0  256.0  222.0  130.0
# 2018-04-17 03:00:00  265.0  25.0  286.0  ...  154.0   73.0  133.0  137.0
# 2018-04-17 04:00:00  272.0  25.0  243.0  ...  116.0   77.0  172.0  252.0
#
# ...

# %%
split_date = pd.Timestamp('2018-06-30')
train = df1.loc[:split_date]
test = df1.loc[split_date:]

# %%
test
# Out:
#                         X26         X303        X241        X435        X402  \
# Time
# 2018-06-30 00:00:00   998.0   484.910250  243.587881  355.739105  510.492405
# 2018-06-30 01:00:00   987.0   483.130476  254.484386  323.936128  444.379897
# 2018-06-30 02:00:00  1001.0    49.000000  159.000000  109.000000  117.000000
# 2018-06-30 03:00:00  1038.0   192.000000  309.000000  255.000000  288.000000
# 2018-06-30 04:00:00  1412.0   135.000000  222.000000  272.000000  225.000000
# 2018-06-30 05:00:00  1824.0   233.000000  459.000000  272.000000  260.000000
# 2018-06-30 06:00:00  1463.0   159.000000  297.000000  246.000000  214.000000
# 2018-06-30 07:00:00  1408.0   138.000000  338.000000  316.000000  323.000000
# 2018-06-30 08:00:00  1349.0   222.000000  367.000000  320.000000  282.000000
# 2018-06-30 09:00:00  1002.0   160.000000  249.000000  347.000000  457.000000
# 2018-06-30 10:00:00   983.0   194.000000  189.000000  340.000000  465.000000
# ...

# %%
# train_cluster1=train[['X10','X102', 'X105', 'X106', 'X107', 'X110', 'X111', 'X116', 'X120', 'X123', 'X124','X125', 'X126', 'X130', 'X132',
#       'X133', 'X134', 'X139', 'X140', 'X142', 'X143', 'X148', 'X149', 'X155', 'X157', 'X158', 'X16', 'X160', 'X161', 'X163',
#       'X165', 'X166', 'X172', 'X175', 'X176', 'X177', 'X178', 'X18', 'X183', 'X186', 'X187', 'X192', 'X194', 'X195', 'X196',
#       'X20', 'X200', 'X201', 'X205' ,'X206', 'X26', 'X30', 'X31', 'X32','X35', 'X37', 'X41', 'X42', 'X43', 'X44', 'X47', 'X5',
#        'X50', 'X51', 'X55', 'X59', 'X61', 'X62', 'X67', 'X68', 'X7', 'X70', 'X73', 'X75', 'X76', 'X80', 'X82', 'X87', 'X88', 
#       'X91', 'X94']]

# %%
# test_cluster1=test[['X10','X102', 'X105', 'X106', 'X107', 'X110', 'X111', 'X116', 'X120', 'X123', 'X124','X125', 'X126', 'X130', 'X132',
#       'X133', 'X134', 'X139', 'X140', 'X142', 'X143', 'X148', 'X149', 'X155', 'X157', 'X158', 'X16', 'X160', 'X161', 'X163',
#       'X165', 'X166', 'X172', 'X175', 'X176', 'X177', 'X178', 'X18', 'X183', 'X186', 'X187', 'X192', 'X194', 'X195', 'X196',
#       'X20', 'X200', 'X201', 'X205' ,'X206', 'X26', 'X30', 'X31', 'X32','X35', 'X37', 'X41', 'X42', 'X43', 'X44', 'X47', 'X5',
#        'X50', 'X51', 'X55', 'X59', 'X61', 'X62', 'X67', 'X68', 'X7', 'X70', 'X73', 'X75', 'X76', 'X80', 'X82', 'X87', 'X88', 
#       'X91', 'X94']]

# %%
# test_cluster1
# Out:
#                         X10    X102   X105   X106  X107    X110   X111   X116  \
# Time
# 2018-06-30 00:00:00  2169.0   432.0  206.0  328.0  26.0    89.0  147.0  210.0
# 2018-06-30 01:00:00  2009.0   461.0  163.0  420.0  27.0   136.0  122.0  229.0
# 2018-06-30 02:00:00  2092.0   442.0  210.0  341.0  27.0    60.0  255.0  204.0
# 2018-06-30 03:00:00  2219.0   353.0  192.0  357.0  27.0    59.0  165.0  176.0
# 2018-06-30 04:00:00  1982.0   333.0  161.0  361.0  27.0    68.0  147.0  219.0
# 2018-06-30 05:00:00  2234.0   357.0  208.0  396.0  27.0    70.0  147.0  228.0
# 2018-06-30 06:00:00  2116.0   381.0  188.0  350.0  27.0    93.0  121.0  174.0
# 2018-06-30 07:00:00  4412.0   464.0  202.0  382.0  27.0    84.0  163.0  189.0
# 2018-06-30 08:00:00  6107.0   490.0  196.0  372.0  27.0    63.0  128.0  109.0
# 2018-06-30 09:00:00  7737.0   419.0  154.0  382.0  27.0   376.0  168.0  165.0
# 2018-06-30 10:00:00  8430.0   460.0  206.0  371.0  26.0   389.0  254.0  140.0
# ...

# %%
# from sklearn.preprocessing import MinMaxScaler
# sc = MinMaxScaler()

# train_cluster1_sc = sc.fit_transform(train_cluster1)
# test_cluster1_sc = sc.fit_transform(test_cluster1)

# train_cluster1_sc_df = pd.DataFrame(train_cluster1_sc, columns=train_cluster1.columns, index = train_cluster1.index)
# test_cluster1_sc_df = pd.DataFrame(test_cluster1_sc, columns=test_cluster1.columns, index = test_cluster1.index)
# train_cluster1_sc_df1 = train_cluster1_sc_df.copy()
# test_cluster1_sc_df1 = test_cluster1_sc_df.copy()
# test_cluster1_sc_df1.head()
# Out:
#                           X10      X102      X105      X106  X107      X110  \
# Time
# 2018-06-30 00:00:00  0.024413  0.029342  0.753623  0.200000   0.0  0.009804
# 2018-06-30 01:00:00  0.003525  0.037937  0.130435  1.000000   1.0  0.025163
# 2018-06-30 02:00:00  0.014360  0.032306  0.811594  0.313043   1.0  0.000327
# 2018-06-30 03:00:00  0.030940  0.005928  0.550725  0.452174   1.0  0.000000
# 2018-06-30 04:00:00  0.000000  0.000000  0.101449  0.486957   1.0  0.002941
#
#                          X111      X116      X120      X123  ...       X70  \
# Time                                                         ...
# 2018-06-30 00:00:00  0.280423  0.750000  0.162826  1.000000  ...  0.015115
# 2018-06-30 01:00:00  0.148148  0.871795  0.021505  0.823529  ...  0.001463
# 2018-06-30 02:00:00  0.851852  0.711538  0.062980  0.794118  ...  0.013652
# 2018-06-30 03:00:00  0.375661  0.532051  0.099846  0.705882  ...  0.002925
# ...

# %%
# train_cluster3=train[['X312', 'X313', 'X314', 'X315', 'X320', 'X323', 'X326', 'X329', 'X330', 'X331', 'X333', 'X337', 'X341',
#                       'X347', 'X349', 'X350', 'X352', 'X353', 'X354', 'X357', 'X358', 'X363', 'X364', 'X367', 'X368', 'X371',
#                       'X376', 'X377', 'X378', 'X379', 'X383', 'X386', 'X389', 'X393', 'X396', 'X397', 'X398', 'X399', 'X402',
#                       'X403', 'X405', 'X406', 'X407', 'X408', 'X410', 'X412', 'X414', 'X419', 'X421', 'X422', 'X423', 'X426',
#                       'X427', 'X431', 'X435', 'X443', 'X445', 'X446', 'X449', 'X450', 'X455', 'X457', 'X459', 'X460', 'X462',
#                       'X468', 'X470', 'X472', 'X473', 'X481']]

# %%
# test_cluster3=test[['X312', 'X313', 'X314', 'X315', 'X320', 'X323', 'X326', 'X329', 'X330', 'X331', 'X333', 'X337', 'X341',
#                       'X347', 'X349', 'X350', 'X352', 'X353', 'X354', 'X357', 'X358', 'X363', 'X364', 'X367', 'X368', 'X371',
#                       'X376', 'X377', 'X378', 'X379', 'X383', 'X386', 'X389', 'X393', 'X396', 'X397', 'X398', 'X399', 'X402',
#                       'X403', 'X405', 'X406', 'X407', 'X408', 'X410', 'X412', 'X414', 'X419', 'X421', 'X422', 'X423', 'X426',
#                       'X427', 'X431', 'X435', 'X443', 'X445', 'X446', 'X449', 'X450', 'X455', 'X457', 'X459', 'X460', 'X462',
#                       'X468', 'X470', 'X472', 'X473', 'X481']]

# %%
# test_cluster3
# Out:
#                             X312        X313        X314        X315  \
# Time
# 2018-06-30 00:00:00   420.031523  130.120656  184.211185  344.723759
# 2018-06-30 01:00:00   318.185145  149.096565  183.807831  333.682551
# 2018-06-30 02:00:00    51.000000   83.000000   36.000000  109.000000
# 2018-06-30 03:00:00    93.000000  151.000000  163.000000  289.000000
# 2018-06-30 04:00:00   104.000000  111.000000  146.000000  228.000000
# 2018-06-30 05:00:00    90.000000  119.000000  141.000000  267.000000
# 2018-06-30 06:00:00    96.000000  117.000000  141.000000  369.000000
# 2018-06-30 07:00:00   108.000000  109.000000  167.000000  320.000000
# 2018-06-30 08:00:00   386.000000   90.000000  401.000000  350.000000
# 2018-06-30 09:00:00   320.000000  149.000000  301.000000  458.000000
# 2018-06-30 10:00:00   304.000000  287.000000  247.000000  371.000000
# 2018-06-30 11:00:00   341.000000  357.000000  209.000000  414.000000
# ...

# %%
# from sklearn.preprocessing import MinMaxScaler
# sc = MinMaxScaler()

# train_cluster3_sc = sc.fit_transform(train_cluster3)
# test_cluster3_sc = sc.fit_transform(test_cluster3)

# train_cluster3_sc_df = pd.DataFrame(train_cluster3_sc, columns=train_cluster3.columns, index = train_cluster3.index)
# test_cluster3_sc_df = pd.DataFrame(test_cluster3_sc, columns=test_cluster3.columns, index = test_cluster3.index)
# train_cluster3_sc_df1 = train_cluster3_sc_df.copy()
# test_cluster3_sc_df1 = test_cluster3_sc_df.copy()
# test_cluster3_sc_df1.head()
# Out:
#                          X312      X313      X314      X315      X320  \
# Time
# 2018-06-30 00:00:00  0.333061  0.110353  0.406058  0.675426  0.729581
# 2018-06-30 01:00:00  0.241142  0.154793  0.404953  0.643790  0.877493
# 2018-06-30 02:00:00  0.000000  0.000000  0.000000  0.000000  0.000000
# 2018-06-30 03:00:00  0.037906  0.159251  0.347945  0.515759  0.457317
# 2018-06-30 04:00:00  0.047834  0.065574  0.301370  0.340974  0.585366
#
#                          X323      X326      X329      X330      X331  ...  \
# Time                                                                   ...
# 2018-06-30 00:00:00  0.677444  0.261418  0.814703  0.532277  0.497159  ...
# 2018-06-30 01:00:00  0.606794  0.219874  0.673702  0.404089  0.422979  ...
# 2018-06-30 02:00:00  0.000000  0.000000  0.117647  0.092649  0.000000  ...
# 2018-06-30 03:00:00  0.332362  0.085714  0.678201  0.281974  0.147368  ...
# 2018-06-30 04:00:00  0.320700  0.082707  0.685121  0.252769  0.136842  ...
#
# ...

# %%
# from sklearn.preprocessing import MinMaxScaler
# sc = MinMaxScaler()

# train_sc = sc.fit_transform(train)
# test_sc = sc.fit_transform(test)

# print(train_sc)
# print(test_sc)
# Out:
# [[9.00347912e-02 1.80312787e-01 3.55140187e-01 ... 1.02373720e-02
#   5.66893424e-04 1.70731707e-01]
#  [1.13645288e-01 1.53173873e-01 2.07476636e-01 ... 2.66621667e-02
#   2.83446712e-04 1.80640244e-01]
#  [1.31200170e-01 1.43054278e-01 2.39252336e-01 ... 2.35122061e-02
#   5.66893424e-04 1.53201220e-01]
#  ...
#  [8.48673201e-02 7.38378657e-02 4.95674854e-01 ... 1.84497694e-01
#   2.83446712e-04 2.02383771e-01]
#  [6.88501076e-02 0.00000000e+00 0.00000000e+00 ... 9.44988188e-03
#   8.50340136e-04 0.00000000e+00]
#  [6.83719818e-02 1.99130750e-01 3.48762395e-01 ... 1.25998425e-02
#   0.00000000e+00 1.84267504e-01]]
# [[0.0259434  0.2653136  0.2819596  ... 0.01348113 0.         0.95323728]
#  [0.0129717  0.26423036 0.31828129 ... 0.         1.         0.93812326]
#  [0.02948113 0.         0.         ... 0.02741162 1.         0.        ]
#  ...
#  [0.47523585 0.50760803 0.92       ... 0.48816657 0.         0.7260274 ]
# ...

# %%
# train_sc_df = pd.DataFrame(train_sc, columns=train.columns, index = train.index)
# test_sc_df = pd.DataFrame(test_sc, columns=test.columns, index = test.index)
# train_sc_df1 = train_sc_df.copy()
# test_sc_df1 = test_sc_df.copy()
# train_sc_df.head()
# Out:
#                           X26      X303      X241      X435      X402  \
# Time
# 2018-04-17 00:00:00  0.090035  0.180313  0.355140  0.467391  0.061214
# 2018-04-17 01:00:00  0.113645  0.153174  0.207477  0.442547  0.060185
# 2018-04-17 02:00:00  0.131200  0.143054  0.239252  0.434783  0.046296
# 2018-04-17 03:00:00  0.144253  0.101656  0.259813  0.394410  0.050412
# 2018-04-17 04:00:00  0.153957  0.132935  0.358879  0.423913  0.058642
#
#                          X352      X305      X350      X326      X299  ...  \
# Time                                                                   ...
# 2018-04-17 00:00:00  0.124770  0.227472  0.182303  0.013773  0.198175  ...
# 2018-04-17 01:00:00  0.135218  0.155731  0.166311  0.013773  0.182529  ...
# 2018-04-17 02:00:00  0.059004  0.110236  0.255864  0.014619  0.198175  ...
# 2018-04-17 03:00:00  0.038722  0.148731  0.194030  0.013773  0.327249  ...
# 2018-04-17 04:00:00  0.041180  0.068241  0.201493  0.013773  0.271186  ...
#
# ...

# %%
# test_sc_df
# Out:
#                           X26      X303      X241      X435      X402  \
# Time
# 2018-06-30 00:00:00  0.025943  0.265314  0.281960  0.586079  0.743842
# 2018-06-30 01:00:00  0.012972  0.264230  0.318281  0.510537  0.618866
# 2018-06-30 02:00:00  0.029481  0.000000  0.000000  0.000000  0.000000
# 2018-06-30 03:00:00  0.073113  0.087036  0.500000  0.346793  0.323251
# 2018-06-30 04:00:00  0.514151  0.052343  0.210000  0.387173  0.204159
# 2018-06-30 05:00:00  1.000000  0.111990  1.000000  0.387173  0.270321
# 2018-06-30 06:00:00  0.574292  0.066951  0.460000  0.325416  0.183365
# 2018-06-30 07:00:00  0.509434  0.054169  0.596667  0.491686  0.389414
# 2018-06-30 08:00:00  0.439858  0.105295  0.693333  0.501188  0.311909
# 2018-06-30 09:00:00  0.030660  0.067559  0.300000  0.565321  0.642722
# 2018-06-30 10:00:00  0.008255  0.088253  0.100000  0.548694  0.657845
# 2018-06-30 11:00:00  0.063679  0.062690  0.066667  1.000000  0.860113
# ...

# %%
train.iloc[:, 0]
# Out:
# Time
# 2018-04-17 00:00:00    1088.615532
# 2018-04-17 01:00:00    1187.378239
# 2018-04-17 02:00:00    1260.810311
# 2018-04-17 03:00:00    1315.408542
# 2018-04-17 04:00:00    1356.003432
# 2018-04-17 05:00:00    1386.186554
# 2018-04-17 06:00:00    1408.628317
# 2018-04-17 07:00:00    1425.314221
# 2018-04-17 08:00:00    1437.720529
# 2018-04-17 09:00:00    1446.944870
# 2018-04-17 10:00:00    1453.803354
# 2018-04-17 11:00:00    1458.902776
# 2018-04-17 12:00:00    1462.694299
# 2018-04-17 13:00:00    1465.513373
# 2018-04-17 14:00:00    1467.609412
# 2018-04-17 15:00:00    1469.167859
# 2018-04-17 16:00:00    1470.326596
# 2018-04-17 17:00:00    1471.188141
# 2018-04-17 18:00:00    1471.828716
# 2018-04-17 19:00:00    1472.304997
# 2018-04-17 20:00:00    1472.659122
# 2018-04-17 21:00:00    1472.922421
# 2018-04-17 22:00:00    1473.118189
# 2018-04-17 23:00:00    1473.263746
# 2018-04-18 00:00:00    1088.615532
# 2018-04-18 01:00:00    1187.378239
# ...

# %%
test.iloc[:, 0].to_frame()
# Out:
#                         X26
# Time
# 2018-06-30 00:00:00   998.0
# 2018-06-30 01:00:00   987.0
# 2018-06-30 02:00:00  1001.0
# 2018-06-30 03:00:00  1038.0
# 2018-06-30 04:00:00  1412.0
# 2018-06-30 05:00:00  1824.0
# 2018-06-30 06:00:00  1463.0
# 2018-06-30 07:00:00  1408.0
# 2018-06-30 08:00:00  1349.0
# 2018-06-30 09:00:00  1002.0
# 2018-06-30 10:00:00   983.0
# 2018-06-30 11:00:00  1030.0
# 2018-06-30 12:00:00  1013.0
# 2018-06-30 13:00:00   989.0
# 2018-06-30 14:00:00   990.0
# 2018-06-30 15:00:00  1179.0
# 2018-06-30 16:00:00  1703.0
# 2018-06-30 17:00:00  1504.0
# 2018-06-30 18:00:00  1271.0
# 2018-06-30 19:00:00  1255.0
# 2018-06-30 20:00:00  1596.0
# 2018-06-30 21:00:00  1379.0
# 2018-06-30 22:00:00  1000.0
# 2018-06-30 23:00:00   976.0

# %%
window_size = 25

# for X in df.columns:
for s in range(1,window_size):
    train_sc_df1['{}_shift_{}'.format(s)]=train.iloc[:, 0].to_frame().shift(s)
    test_sc_df1['{}_shift_{}'.format(s)]=test.iloc[:, 0].to_frame().shift(s)
train_sc_df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-95-5efd90954f2c> in <module>
#       3 # for X in df.columns:
#       4 for s in range(1,window_size):
# ----> 5     train_sc_df1['{}_shift_{}'.format(s)]=train.iloc[:, 0].to_frame().shift(s)
#       6     test_sc_df1['{}_shift_{}'.format(s)]=test.iloc[:, 0].to_frame().shift(s)
#       7 train_sc_df
#
# IndexError: tuple index out of range

# %%
train_sc_df1.head()
# Out:
#                           X26      X303      X241      X435      X402  \
# Time
# 2017-07-01 00:00:00  0.130223  0.049852  0.052251  0.054876  0.044383
# 2017-07-01 01:00:00  0.129897  0.064192  0.054180  0.067906  0.045400
# 2017-07-01 02:00:00  0.125014  0.062473  0.057413  0.067548  0.047326
# 2017-07-01 03:00:00  0.123678  0.058751  0.053535  0.065331  0.044112
# 2017-07-01 04:00:00  0.188073  0.050574  0.057126  0.065055  0.045896
#
#                          X352      X305      X350      X326      X299  ...  \
# Time                                                                   ...
# 2017-07-01 00:00:00  0.049728  0.043007  0.053386  0.040881  0.033658  ...
# 2017-07-01 01:00:00  0.051833  0.055175  0.065487  0.042328  0.044310  ...
# 2017-07-01 02:00:00  0.051408  0.052111  0.067772  0.044729  0.050672  ...
# 2017-07-01 03:00:00  0.047993  0.051427  0.064224  0.048571  0.050216  ...
# 2017-07-01 04:00:00  0.047581  0.043046  0.066220  0.043221  0.049298  ...
#
# ...

# %%
print(train_sc_df1.columns)
print(train_sc_df.columns)
# Out:
# Index(['X26', 'X303', 'X241', 'X435', 'X402', 'X352', 'X305', 'X350', 'X326',
#        'X299',
#        ...
#        'X230_shift_15', 'X230_shift_16', 'X230_shift_17', 'X230_shift_18',
#        'X230_shift_19', 'X230_shift_20', 'X230_shift_21', 'X230_shift_22',
#        'X230_shift_23', 'X230_shift_24'],
#       dtype='object', length=5000)
# Index(['X26', 'X303', 'X241', 'X435', 'X402', 'X352', 'X305', 'X350', 'X326',
#        'X299',
#        ...
#        'X283', 'X329', 'X223', 'X266', 'X20', 'X443', 'X347', 'X75', 'X107',
#        'X230'],
#       dtype='object', length=200)

# %%
train_sc_df1.iloc[:,200:]
# Out:
#                      X26_shift_1  X26_shift_2  X26_shift_3  X26_shift_4  \
# Time
# 2017-07-01 00:00:00          NaN          NaN          NaN          NaN
# 2017-07-01 01:00:00     0.130223          NaN          NaN          NaN
# 2017-07-01 02:00:00     0.129897     0.130223          NaN          NaN
# 2017-07-01 03:00:00     0.125014     0.129897     0.130223          NaN
# 2017-07-01 04:00:00     0.123678     0.125014     0.129897     0.130223
# ...                          ...          ...          ...          ...
# 2018-05-30 20:00:00     0.444110     0.318082     0.305205     0.313699
# 2018-05-30 21:00:00     0.406027     0.444110     0.318082     0.305205
# 2018-05-30 22:00:00     0.527397     0.406027     0.444110     0.318082
# 2018-05-30 23:00:00     0.367671     0.527397     0.406027     0.444110
# 2018-05-31 00:00:00     0.135890     0.367671     0.527397     0.406027
#
#                      X26_shift_5  X26_shift_6  X26_shift_7  X26_shift_8  \
# Time
# ...

# %%
X_train=train_sc_df1.iloc[24:, 200:]
X_train
# Out:
#                      X26_shift_1  X26_shift_2  X26_shift_3  X26_shift_4  \
# Time
# 2017-07-02 00:00:00     0.151374     0.182233     0.236994     0.243676
# 2017-07-02 01:00:00     0.130223     0.151374     0.182233     0.236994
# 2017-07-02 02:00:00     0.129897     0.130223     0.151374     0.182233
# 2017-07-02 03:00:00     0.125014     0.129897     0.130223     0.151374
# 2017-07-02 04:00:00     0.123678     0.125014     0.129897     0.130223
# ...                          ...          ...          ...          ...
# 2018-05-30 20:00:00     0.444110     0.318082     0.305205     0.313699
# 2018-05-30 21:00:00     0.406027     0.444110     0.318082     0.305205
# 2018-05-30 22:00:00     0.527397     0.406027     0.444110     0.318082
# 2018-05-30 23:00:00     0.367671     0.527397     0.406027     0.444110
# 2018-05-31 00:00:00     0.135890     0.367671     0.527397     0.406027
#
#                      X26_shift_5  X26_shift_6  X26_shift_7  X26_shift_8  \
# Time
# ...

# %%
X_test = test_sc_df1.iloc[24:,200:]

# %%
train_sc_df.iloc[24:]
# Out:
#                           X26      X303      X241      X435      X402  \
# Time
# 2017-07-02 00:00:00  0.130223  0.049852  0.052251  0.054876  0.044383
# 2017-07-02 01:00:00  0.129897  0.064192  0.054180  0.067906  0.045400
# 2017-07-02 02:00:00  0.125014  0.062473  0.057413  0.067548  0.047326
# 2017-07-02 03:00:00  0.123678  0.058751  0.053535  0.065331  0.044112
# 2017-07-02 04:00:00  0.188073  0.050574  0.057126  0.065055  0.045896
# ...                       ...       ...       ...       ...       ...
# 2018-05-30 20:00:00  0.406027  0.259254  0.047748  0.096574  0.109817
# 2018-05-30 21:00:00  0.527397  0.130395  0.053145  0.108301  0.153356
# 2018-05-30 22:00:00  0.367671  0.111657  0.047748  0.078639  0.132557
# 2018-05-30 23:00:00  0.135890  0.152665  0.051692  0.063463  0.060455
# 2018-05-31 00:00:00  0.122466  0.100906  0.042973  0.049897  0.048530
#
#                          X352      X305      X350      X326      X299  ...  \
# ...

# %%
y_train = train_sc_df.iloc[24:]
y_train
# Out:
#                           X26      X303      X241      X435      X402  \
# Time
# 2017-07-02 00:00:00  0.130223  0.049852  0.052251  0.054876  0.044383
# 2017-07-02 01:00:00  0.129897  0.064192  0.054180  0.067906  0.045400
# 2017-07-02 02:00:00  0.125014  0.062473  0.057413  0.067548  0.047326
# 2017-07-02 03:00:00  0.123678  0.058751  0.053535  0.065331  0.044112
# 2017-07-02 04:00:00  0.188073  0.050574  0.057126  0.065055  0.045896
# ...                       ...       ...       ...       ...       ...
# 2018-05-30 20:00:00  0.406027  0.259254  0.047748  0.096574  0.109817
# 2018-05-30 21:00:00  0.527397  0.130395  0.053145  0.108301  0.153356
# 2018-05-30 22:00:00  0.367671  0.111657  0.047748  0.078639  0.132557
# 2018-05-30 23:00:00  0.135890  0.152665  0.051692  0.063463  0.060455
# 2018-05-31 00:00:00  0.122466  0.100906  0.042973  0.049897  0.048530
#
#                          X352      X305      X350      X326      X299  ...  \
# ...

# %%
y_test = test_sc_df.iloc[24:]

# %%
print(type(X_train))
print(X_train.shape)
X_train = X_train.values
print(type(y_train))
print(y_train.shape)
y_train = y_train.values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (7993, 4800)
# <class 'pandas.core.frame.DataFrame'>
# (7993, 200)

# %%
print(type(X_test))
print(X_test.shape)
X_test = X_test.values
print(type(y_test))
print(y_test.shape)
y_test = y_test.values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (720, 4800)
# <class 'pandas.core.frame.DataFrame'>
# (720, 200)

# %%
train_X=X_train.reshape(-1,24,200)

# %%
X_train_t = X_train.reshape(train_X.shape[0], train_X.shape[1], 200)
print("최종 DATA")
print(X_train_t.shape)
print(X_train_t)
print(y_train)
# Out:
# 최종 DATA
# (7993, 24, 200)
# [[[0.15137357 0.18223251 0.23699371 ... 0.06257157 0.0612504  0.05802892]
#   [0.05726131 0.053961   0.05349653 ... 0.08281979 0.0785843  0.07047569]
#   [0.05959784 0.05312291 0.05070746 ... 0.07600107 0.08308565 0.08693013]
#   ...
#   [0.06494222 0.07664643 0.07256936 ... 0.0454608  0.04615404 0.04135609]
#   [0.036922   0.04060607 0.04088697 ... 0.03464085 0.03109635 0.04957586]
#   [0.04252751 0.04174542 0.04355224 ... 0.04998708 0.04840034 0.04886771]]
#
#  [[0.13022331 0.15137357 0.18223251 ... 0.06920236 0.06257157 0.0612504 ]
#   [0.05802892 0.05726131 0.053961   ... 0.08260321 0.08281979 0.0785843 ]
#   [0.07047569 0.05959784 0.05312291 ... 0.06025209 0.07600107 0.08308565]
#   ...
#   [0.04580632 0.06494222 0.07664643 ... 0.04785476 0.0454608  0.04615404]
#   [0.04135609 0.036922   0.04060607 ... 0.03640123 0.03464085 0.03109635]
#   [0.04957586 0.04252751 0.04174542 ... 0.0482759  0.04998708 0.04840034]]
#
# ...

# %%
del model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-a7ab210f85a1> in <module>
# ----> 1 del model
#
# NameError: name 'model' is not defined

# %%
from keras.layers import LSTM 
from keras.models import Sequential 
from keras.layers import Dense 
import keras.backend as K 
from keras.callbacks import EarlyStopping


K.clear_session()
    
model = Sequential() # Sequeatial Model 
model.add(LSTM(20, input_shape=(X_train_t.shape[1], 200))) # (timestep, feature) 
model.add(Dense(200)) # output = 1 
model.compile(loss='mean_squared_error', optimizer='adam') 
model.summary()
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
early_stop = EarlyStopping(monitor='loss', patience=10)

history = model.fit(X_train_t, y_train, epochs=100, batch_size=30, callbacks=[early_stop])
# Out:
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
# 7993/7993 [==============================] - 6s 768us/step - loss: 0.0075 0s - loss: 0.008 - ETA: 0s - loss: 0.007 - ETA: 0s - loss: 0.00 - ETA: 0s - los
# Epoch 2/100
# 7993/7993 [==============================] - 5s 620us/step - loss: 0.0038 1s  - ETA: 0s - l
# Epoch 3/100
# 7993/7993 [==============================] - 5s 617us/step - loss: 0.0031 0s - loss: 0.00
# Epoch 4/100
# 7993/7993 [==============================] - 5s 571us/step - loss: 0.0028 4s - lo
# Epoch 5/100
# 7993/7993 [==============================] - 5s 567us/step - loss: 0.0027 - ETA: 0s - loss: 0.
# Epoch 6/100
# ...

# %%
test_X = X_test.reshape(-1, 24, 200)

# %%
X_test_t = X_test.reshape(test_X.shape[0], test_X.shape[1], 200)
print("최종 DATA")
print(X_test_t.shape)
print(X_test_t)
print(y_test)
# Out:
# 최종 DATA
# (720, 24, 200)
# [[[0.24987277 0.21857506 0.34223919 ... 0.05739514 0.05665931 0.13833701]
#   [0.05592347 0.0647535  0.0794702  ... 0.03656354 0.15571465 0.04551266]
#   [0.06520072 0.03068269 0.02556891 ... 0.05505909 0.0354569  0.05995964]
#   ...
#   [0.14200596 0.15458457 0.12346905 ... 0.05328071 0.03305377 0.03157375]
#   [0.04637395 0.06610755 0.07153429 ... 0.02565789 0.02565789 0.10592105]
#   [0.04934211 0.04210526 0.04013158 ... 0.13945578 0.11100804 0.12646877]]
#
#  [[0.10025445 0.24987277 0.21857506 ... 0.0544518  0.05739514 0.05665931]
#   [0.13833701 0.05592347 0.0647535  ... 0.05241626 0.03656354 0.15571465]
#   [0.04551266 0.06520072 0.03068269 ... 0.02940329 0.05505909 0.0354569 ]
#   ...
#   [0.10095995 0.14200596 0.15458457 ... 0.02910705 0.05328071 0.03305377]
#   [0.03157375 0.04637395 0.06610755 ... 0.02894737 0.02565789 0.02565789]
#   [0.10592105 0.04934211 0.04210526 ... 0.1187384  0.13945578 0.11100804]]
#
# ...

# %%
print(X_test_t)
# Out:
# [[[0.24987277 0.21857506 0.34223919 ... 0.05739514 0.05665931 0.13833701]
#   [0.05592347 0.0647535  0.0794702  ... 0.03656354 0.15571465 0.04551266]
#   [0.06520072 0.03068269 0.02556891 ... 0.05505909 0.0354569  0.05995964]
#   ...
#   [0.14200596 0.15458457 0.12346905 ... 0.05328071 0.03305377 0.03157375]
#   [0.04637395 0.06610755 0.07153429 ... 0.02565789 0.02565789 0.10592105]
#   [0.04934211 0.04210526 0.04013158 ... 0.13945578 0.11100804 0.12646877]]
#
#  [[0.10025445 0.24987277 0.21857506 ... 0.0544518  0.05739514 0.05665931]
#   [0.13833701 0.05592347 0.0647535  ... 0.05241626 0.03656354 0.15571465]
#   [0.04551266 0.06520072 0.03068269 ... 0.02940329 0.05505909 0.0354569 ]
#   ...
#   [0.10095995 0.14200596 0.15458457 ... 0.02910705 0.05328071 0.03305377]
#   [0.03157375 0.04637395 0.06610755 ... 0.02894737 0.02565789 0.02565789]
#   [0.10592105 0.04934211 0.04210526 ... 0.1187384  0.13945578 0.11100804]]
#
# ...

# %%
y_pred = model.predict(X_test_t)
print(y_pred)
# Out:
# [[ 0.13900095  0.13575104  0.1192886  ...  0.05999371 -0.01879326
#    0.09113035]
#  [ 0.13815886  0.12700681  0.10452296 ...  0.05644889 -0.0050355
#    0.08335983]
#  [ 0.15654013  0.09503806  0.07729005 ...  0.08515071 -0.05690854
#    0.06502616]
#  ...
#  [ 0.21053228  0.13894244  0.11840787 ...  0.26399395 -0.16746368
#    0.09788727]
#  [ 0.14502494  0.12130752  0.10864382 ...  0.16778946 -0.19966899
#    0.09127726]
#  [ 0.13268432  0.05352736  0.05384652 ...  0.13932472 -0.18298118
#    0.05311348]]

# %%
y_pred_sc = sc.inverse_transform(y_pred)

# %%
y_pred_sc
# Out:
# array([[ 1.5112737 ,  0.53078043,  0.35271645, ...,  0.6711041 ,
#         -0.04030263,  0.35571557],
#        [ 1.5079644 ,  0.49974716,  0.31611243, ...,  0.6396048 ,
#          0.00823474,  0.3305857 ],
#        [ 1.5802027 ,  0.38629007,  0.24860203, ...,  0.89464927,
#         -0.17477332,  0.2712946 ],
#        ...,
#        [ 1.7923919 ,  0.5421067 ,  0.3505331 , ...,  2.4838502 ,
#         -0.5648119 ,  0.37756744],
#        [ 1.534948  ,  0.47952038,  0.32632804, ...,  1.6289772 ,
#         -0.6784322 ,  0.35619068],
#        [ 1.4864495 ,  0.23896861,  0.1904855 , ...,  1.3760395 ,
#         -0.6195576 ,  0.23276901]], dtype=float32)

# %%
y_pred_df = pd.DataFrame(data = y_pred_sc)

# %%
y_pred_df.to_csv('./SUHYUN/y_pred_df.csv', index = False)

# %%
y_real=test.iloc[24:, :]

# %%
y_real.head(50)
# Out:
#                        X26   X303   X241   X435   X402   X352   X305   X350  \
# Time
# 2018-06-01 00:00:00  1.359  0.456  0.252  0.232  0.278  0.283  0.559  0.347
# 2018-06-01 01:00:00  1.347  0.405  0.213  0.222  0.249  0.168  0.509  0.348
# 2018-06-01 02:00:00  1.307  0.390  0.213  0.230  0.189  0.144  0.307  0.218
# 2018-06-01 03:00:00  1.402  0.267  0.287  0.214  0.204  0.146  0.302  0.223
# 2018-06-01 04:00:00  1.801  0.264  0.178  0.215  0.293  0.135  0.313  0.271
# 2018-06-01 05:00:00  1.917  0.251  0.455  0.247  0.211  0.230  0.306  0.246
# 2018-06-01 06:00:00  2.053  0.244  0.257  0.242  0.195  0.263  0.540  0.224
# 2018-06-01 07:00:00  1.311  0.611  0.324  0.319  0.384  0.119  0.851  0.343
# 2018-06-01 08:00:00  1.254  0.591  0.411  0.490  0.363  0.115  0.358  0.353
# 2018-06-01 09:00:00  1.350  0.297  0.357  0.385  0.247  0.138  0.366  0.277
# 2018-06-01 10:00:00  1.445  0.199  0.169  0.167  0.211  0.170  0.211  0.146
# ...

# %%
y_pred_df.values.reshape(-1).size
# Out:
# 144000

# %%
y_real.values.reshape(-1).size
# Out:
# 144000

# %%
import math

# %%
out = 0
for i in range(y_real.values.reshape(-1).shape[0]):
    a = y_real.values.reshape(-1)[i]
    b = y_pred_df.values.reshape(-1)[i]
    c = a+b
    if c == 0:
        continue
    out += math.fabs(a - b) / c
out *= (200.0 / y_real.values.reshape(-1).shape[0])
print(out)
# Out:
# 54.84177033175575

# %%
test

# %%
y_pred_df
