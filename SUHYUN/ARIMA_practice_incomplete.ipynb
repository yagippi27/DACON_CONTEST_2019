# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train=pd.read_csv("./DACON_DATASET/train.csv")
train['Time']=pd.to_datetime(train['Time']).dt.strftime('%Y-%m-%d %H:%M')
train=train.set_index('Time')
train.head()
# Out:
#                   X692  X1272  X553  X1299  X4  X598  X1003  X1010  X1216  \
# Time
# 2016-07-26 11:00   NaN    NaN   NaN    NaN NaN   NaN    NaN    NaN    NaN
# 2016-07-26 12:00   NaN    NaN   NaN    NaN NaN   NaN    NaN    NaN    NaN
# 2016-07-26 13:00   NaN    NaN   NaN    NaN NaN   NaN    NaN    NaN    NaN
# 2016-07-26 14:00   NaN    NaN   NaN    NaN NaN   NaN    NaN    NaN    NaN
# 2016-07-26 15:00   NaN    NaN   NaN    NaN NaN   NaN    NaN    NaN    NaN
#
#                   X1047  ...  X1164  X656  X1287  X324  X767  X1271  X1288  \
# Time                     ...
# 2016-07-26 11:00    NaN  ...    NaN   NaN    NaN   NaN   NaN    NaN    NaN
# 2016-07-26 12:00    NaN  ...    NaN   NaN    NaN   NaN   NaN    NaN    NaN
# 2016-07-26 13:00    NaN  ...    NaN   NaN    NaN   NaN   NaN    NaN    NaN
# 2016-07-26 14:00    NaN  ...    NaN   NaN    NaN   NaN   NaN    NaN    NaN
# 2016-07-26 15:00    NaN  ...    NaN   NaN    NaN   NaN   NaN    NaN    NaN
#
#                   X58  X1033  X1163
# Time
# 2016-07-26 11:00  NaN    NaN    NaN
# 2016-07-26 12:00  NaN    NaN    NaN
# 2016-07-26 13:00  NaN    NaN    NaN
# 2016-07-26 14:00  NaN    NaN    NaN
# 2016-07-26 15:00  NaN    NaN    NaN
#
# [5 rows x 1300 columns]

# %%
train.info()
# <class 'pandas.core.frame.DataFrame'>
# Index: 16909 entries, 2016-07-26 11:00 to 2018-06-30 23:00
# Columns: 1300 entries, X692 to X1163
# dtypes: float64(1300)
# memory usage: 167.8+ MB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16909 entries, 2016-07-26 11:00 to 2018-06-30 23:00
# Columns: 1300 entries, X692 to X1163
# dtypes: float64(1300)
# memory usage: 167.8+ MB

# %%
train_cut=train.loc['2018-02-15 00:00':'2018-04-30 00:00', "X452"]
train_cut.head()
# Out:
# Time
# 2018-02-15 00:00    0.103
# 2018-02-15 01:00    0.276
# 2018-02-15 02:00    0.223
# 2018-02-15 03:00    0.181
# 2018-02-15 04:00    0.157
# Name: X452, dtype: float64

# %%
plt.figure(figsize=(30,10))
train_cut.plot()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(train_cut)
plot_pacf(train_cut)
plt.figure(figsize=(20,4))
plt.show()

# %%
차분해도 소용없어서 진행 안함
# diff_1 = train_cut.diff(periods=1).iloc[1:]
# plt.figure(figsize=(30,10))
# diff_1.plot()
# plt.show()

# %%
# plot_acf(diff_1)
# plot_pacf(diff_1)
# plt.show()

# %%
auto.arima(ts(kings))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-6ebcad017368> in <module>
# ----> 1 auto.arima(ts(kings))
#
# NameError: name 'auto' is not defined

# %%
from statsmodels.tsa.arima_model import ARIMA, ARIMAResults

model = ARIMA(train_cut, order=(0,0,0))
model_fit = model.fit(trend = 'c', full_output = True, disp=1)
print(model_fit.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                   X452   No. Observations:                 1777
# Model:                     ARMA(0, 0)   Log Likelihood                     nan
# Method:                           css   S.D. of innovations                nan
# Date:                Wed, 02 Oct 2019   AIC                                nan
# Time:                        17:46:12   BIC                                nan
# Sample:                    02-15-2018   HQIC                               nan
#                          - 04-30-2018
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const             nan        nan        nan        nan         nan         nan
# ==============================================================================
# C:\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# C:\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:811: RuntimeWarning: invalid value encountered in log
#   llf = -nobs/2.*(log(2*pi) + log(sigma2)) - ssr/(2*sigma2)
# C:\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:811: RuntimeWarning: invalid value encountered in cdouble_scalars
#   llf = -nobs/2.*(log(2*pi) + log(sigma2)) - ssr/(2*sigma2)
# C:\Anaconda3\lib\site-packages\statsmodels\base\model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1892: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
