# %%
import pandas as pd
import numpy as np
import pandas_profiling

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')

# import missingno as msno

# %%
train1 = pd.read_csv("data/train.csv", sep = ",")
test = pd.read_csv("data/test.csv", sep = ",")

# %%
train1.head()
# Out:
#                Time  X692  X1272  X553  X1299  X4  X598  X1003  X1010  X1216  \
# 0  2016-07-26 11:00   NaN    NaN   NaN    NaN NaN   NaN    NaN    NaN    NaN
# 1  2016-07-26 12:00   NaN    NaN   NaN    NaN NaN   NaN    NaN    NaN    NaN
# 2  2016-07-26 13:00   NaN    NaN   NaN    NaN NaN   NaN    NaN    NaN    NaN
# 3  2016-07-26 14:00   NaN    NaN   NaN    NaN NaN   NaN    NaN    NaN    NaN
# 4  2016-07-26 15:00   NaN    NaN   NaN    NaN NaN   NaN    NaN    NaN    NaN
#
#    ...  X1164  X656  X1287  X324  X767  X1271  X1288  X58  X1033  X1163
# 0  ...    NaN   NaN    NaN   NaN   NaN    NaN    NaN  NaN    NaN    NaN
# 1  ...    NaN   NaN    NaN   NaN   NaN    NaN    NaN  NaN    NaN    NaN
# 2  ...    NaN   NaN    NaN   NaN   NaN    NaN    NaN  NaN    NaN    NaN
# 3  ...    NaN   NaN    NaN   NaN   NaN    NaN    NaN  NaN    NaN    NaN
# 4  ...    NaN   NaN    NaN   NaN   NaN    NaN    NaN  NaN    NaN    NaN
#
# [5 rows x 1301 columns]

# %%
test.head()
# Out:
#             Time  X26  X303  X241  X435  X402  X352  X305  X350  X326  ...  \
# 0  2017.7.1 0:00  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  2017.7.1 1:00  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2  2017.7.1 2:00  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3  2017.7.1 3:00  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4  2017.7.1 4:00  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#    X283  X329  X223  X266  X20  X443  X347    X75   X107  X230
# 0   NaN   NaN   NaN   NaN  NaN   NaN   NaN  0.275  0.021   NaN
# 1   NaN   NaN   NaN   NaN  NaN   NaN   NaN  0.222  0.021   NaN
# 2   NaN   NaN   NaN   NaN  NaN   NaN   NaN  0.237  0.021   NaN
# 3   NaN   NaN   NaN   NaN  NaN   NaN   NaN  0.229  0.020   NaN
# 4   NaN   NaN   NaN   NaN  NaN   NaN   NaN  0.202  0.021   NaN
#
# [5 rows x 201 columns]

# %%
train1.shape
# Out:
# (16909, 1301)

# %%
# 데이터가 1도 없는 칼럼 추출
stats = train1.describe()
nullcols = [i for i in range(0, 1300) if stats.iloc[0][i] == 0]

# %%
stats
# Out:
#               X692        X1272         X553        X1299   X4         X598  \
# count  3064.000000  3065.000000  3041.000000  3006.000000  0.0  3041.000000
# mean      0.371506     0.410571     0.519877     0.260363  NaN     0.268325
# std       0.190358     0.272845     0.236184     0.231955  NaN     0.149223
# min       0.049000     0.066000     0.053000     0.017000  NaN     0.034000
# 25%       0.271000     0.225000     0.416000     0.114000  NaN     0.162000
# 50%       0.329000     0.338000     0.485000     0.176500  NaN     0.228000
# 75%       0.430000     0.536000     0.581000     0.339000  NaN     0.346000
# max       4.104000     4.837000     6.232000     5.624000  NaN     2.718000
#
#              X1003        X1010        X1216        X1047  ...        X1164  \
# count  2937.000000  3048.000000  3064.000000  3062.000000  ...  3040.000000
# mean      0.378017     0.424614     0.302138     0.273101  ...     0.410577
# std       0.267603     0.267227     0.157183     0.184067  ...     0.270049
# min       0.052000     0.052000     0.071000     0.037000  ...     0.058000
# 25%       0.207000     0.285000     0.212000     0.163000  ...     0.266000
# 50%       0.274000     0.347500     0.281000     0.216000  ...     0.332000
# 75%       0.483000     0.466000     0.344000     0.313750  ...     0.475000
# max       5.418000     4.426000     2.899000     2.684000  ...     5.929000
#
#               X656        X1287         X324         X767        X1271  \
# count  3066.000000  3035.000000  6766.000000  3040.000000  3065.000000
# mean      0.441267     0.271726     0.141011     0.384662     0.552852
# std       0.295568     0.146547     0.116648     0.254653     0.386933
# min       0.074000     0.022000     0.007000     0.048000     0.045000
# 25%       0.242000     0.198000     0.055000     0.214000     0.251000
# 50%       0.384000     0.233000     0.122000     0.317500     0.477000
# 75%       0.545000     0.309500     0.173000     0.500000     0.758000
# max       4.562000     3.209000     1.768000     4.443000     7.773000
#
#              X1288          X58        X1033        X1163
# count  3034.000000  1747.000000  3044.000000  3041.000000
# mean      0.487484     2.881876     0.356959     0.339762
# std       0.277884     1.915190     0.189310     0.198999
# min       0.041000     0.216000     0.038000     0.057000
# 25%       0.280000     1.360500     0.242000     0.218000
# 50%       0.432000     2.469000     0.326000     0.290000
# 75%       0.663750     4.209500     0.432250     0.449000
# max       4.414000     9.088000     3.921000     5.049000
#
# [8 rows x 1300 columns]

# %%
nullcols
# Out:
# [4, 286, 622, 756, 834, 915, 1024, 1241]

# %%
stats.columns[nullcols]
# Out:
# Index(['X4', 'X24', 'X64', 'X3', 'X22', 'X45', 'X1', 'X34'], dtype='object')

# %%
# 칼럼 제거
train = train1.drop(stats.columns[nullcols], axis=1)

# %%
train.shape
# Out:
# (16909, 1293)

# %%
# Time 데이터 타입 변환 및 인덱스 설정
train['Time'] = pd.to_datetime(train.Time)
train = train.set_index('Time')

test['Time'] = pd.to_datetime(test.Time)
test = test.set_index('Time')

# %%
# Missing values 확인
_, ax = plt.subplots(1,2, figsize=(15,5))
sns.distplot(train.isnull().mean(axis=0), ax=ax[0])
ax[0].set_title("Distribution of Missing values percentage in Train set")

sns.distplot(test.isnull().mean(axis=0), ax=ax[1])
ax[1].set_title('Distribution of Missing Values Percentage in Test set')
plt.show()

# %% [markdown]
# <br><br>
#
# ### 데이터 그래프 그려보기 (클러스터 개수를 파악할 수 있을까?)
# 1. 칼럼별 mean, IQR plot
# 2. 순수 시계열

# %%
stats = train.describe()
stats
# Out:
#               X692        X1272         X553        X1299         X598  \
# count  3064.000000  3065.000000  3041.000000  3006.000000  3041.000000
# mean      0.371506     0.410571     0.519877     0.260363     0.268325
# std       0.190358     0.272845     0.236184     0.231955     0.149223
# min       0.049000     0.066000     0.053000     0.017000     0.034000
# 25%       0.271000     0.225000     0.416000     0.114000     0.162000
# 50%       0.329000     0.338000     0.485000     0.176500     0.228000
# 75%       0.430000     0.536000     0.581000     0.339000     0.346000
# max       4.104000     4.837000     6.232000     5.624000     2.718000
#
#              X1003        X1010        X1216        X1047         X381  ...  \
# count  2937.000000  3048.000000  3064.000000  3062.000000  6737.000000  ...
# mean      0.378017     0.424614     0.302138     0.273101     0.184522  ...
# std       0.267603     0.267227     0.157183     0.184067     0.106575  ...
# min       0.052000     0.052000     0.071000     0.037000     0.009000  ...
# 25%       0.207000     0.285000     0.212000     0.163000     0.100000  ...
# 50%       0.274000     0.347500     0.281000     0.216000     0.156000  ...
# 75%       0.483000     0.466000     0.344000     0.313750     0.248000  ...
# max       5.418000     4.426000     2.899000     2.684000     1.806000  ...
#
#              X1164         X656        X1287         X324         X767  \
# count  3040.000000  3066.000000  3035.000000  6766.000000  3040.000000
# mean      0.410577     0.441267     0.271726     0.141011     0.384662
# std       0.270049     0.295568     0.146547     0.116648     0.254653
# min       0.058000     0.074000     0.022000     0.007000     0.048000
# 25%       0.266000     0.242000     0.198000     0.055000     0.214000
# 50%       0.332000     0.384000     0.233000     0.122000     0.317500
# 75%       0.475000     0.545000     0.309500     0.173000     0.500000
# max       5.929000     4.562000     3.209000     1.768000     4.443000
#
#              X1271        X1288          X58        X1033        X1163
# count  3065.000000  3034.000000  1747.000000  3044.000000  3041.000000
# mean      0.552852     0.487484     2.881876     0.356959     0.339762
# std       0.386933     0.277884     1.915190     0.189310     0.198999
# min       0.045000     0.041000     0.216000     0.038000     0.057000
# 25%       0.251000     0.280000     1.360500     0.242000     0.218000
# 50%       0.477000     0.432000     2.469000     0.326000     0.290000
# 75%       0.758000     0.663750     4.209500     0.432250     0.449000
# max       7.773000     4.414000     9.088000     3.921000     5.049000
#
# [8 rows x 1292 columns]

# %% [markdown]
# #### 1. 미터계량기 별 평균 scatter, IQR graph

# %%
# mean scatter

m_train = pd.DataFrame(stats.loc['mean', :]).sort_values(by=['mean'])
m_train['mID'] = range(1292)

m_train.plot.scatter(x= 'mID', y='mean', figsize=(10,10))

m_below2 = m_train[m_train['mean'] < 2]
m_below2.plot.scatter(x= 'mID', y='mean', figsize=(10,10))

# %%
# IQR & Mean 

minmax_train = stats.loc[['mean','25%', '75%']].T.sort_values(by='mean')
minmax_train['mID'] = range(1292)

minmax_train.head()
# Out:
#            mean    25%    75%  mID
# X118   0.002000  0.002  0.002    0
# X1286  0.005859  0.005  0.006    1
# X74    0.015137  0.007  0.031    2
# X117   0.020870  0.020  0.023    3
# X569   0.030263  0.021  0.022    4

# %%
first = list(map(lambda x,y: (x,y), 
         minmax_train.get("mID"), minmax_train.get("25%")))
third = list(map(lambda x,y: (x,y), 
         minmax_train.get("mID"), minmax_train.get("75%")))
lines = list(map(lambda x,y: [x,y], first, third))
lines
# Out:
# [[(0, 0.002), (0, 0.002)],
#  [(1, 0.005), (1, 0.006)],
#  [(2, 0.006999999999999999), (2, 0.031)],
#  [(3, 0.02), (3, 0.023)],
#  [(4, 0.021), (4, 0.022)],
#  [(5, 0.026), (5, 0.031)],
#  [(6, 0.006), (6, 0.051)],
#  [(7, 0.013), (7, 0.024)],
#  [(8, 0.02), (8, 0.02)],
#  [(9, 0.052000000000000005), (9, 0.083)],
#  [(10, 0.038), (10, 0.08900000000000001)],
#  [(11, 0.055), (11, 0.08800000000000001)],
#  [(12, 0.067), (12, 0.12299999999999998)],
#  [(13, 0.056), (13, 0.11875)],
#  [(14, 0.006999999999999999), (14, 0.14)],
#  [(15, 0.034), (15, 0.151)],
#  [(16, 0.066), (16, 0.134)],
#  [(17, 0.076), (17, 0.099)],
#  [(18, 0.053), (18, 0.099)],
#  [(19, 0.027000000000000003), (19, 0.083)],
#  [(20, 0.026), (20, 0.141)],
#  [(21, 0.08199999999999999), (21, 0.145)],
#  [(22, 0.079), (22, 0.168)],
#  [(23, 0.055), (23, 0.173)],
#  [(24, 0.054000000000000006), (24, 0.161)],
#  [(25, 0.097), (25, 0.179)],
#  [(26, 0.081), (26, 0.199)],
#  [(27, 0.006), (27, 0.11)],
#  [(28, 0.08800000000000001), (28, 0.199)],
#  [(29, 0.011), (29, 0.244)],
#  [(30, 0.065), (30, 0.209)],
#  [(31, 0.08199999999999999), (31, 0.206)],
#  [(32, 0.106), (32, 0.153)],
#  [(33, 0.083), (33, 0.20725)],
#  [(34, 0.073), (34, 0.224)],
#  [(35, 0.032), (35, 0.177)],
#  [(36, 0.097), (36, 0.228)],
#  [(37, 0.07200000000000001), (37, 0.206)],
#  [(38, 0.118), (38, 0.188)],
#  [(39, 0.083), (39, 0.223)],
#  [(40, 0.07400000000000001), (40, 0.21375)],
#  [(41, 0.131), (41, 0.192)],
#  [(42, 0.12), (42, 0.197)],
#  [(43, 0.102), (43, 0.182)],
#  [(44, 0.098), (44, 0.22275)],
#  [(45, 0.126), (45, 0.218)],
#  [(46, 0.107), (46, 0.2145)],
#  [(47, 0.097), (47, 0.232)],
#  [(48, 0.09), (48, 0.234)],
#  [(49, 0.066), (49, 0.21600000000000005)],
#  [(50, 0.115), (50, 0.224)],
#  [(51, 0.097), (51, 0.24)],
#  [(52, 0.1), (52, 0.248)],
#  [(53, 0.041), (53, 0.277)],
#  [(54, 0.114), (54, 0.234)],
#  [(55, 0.092), (55, 0.249)],
#  [(56, 0.117), (56, 0.223)],
#  [(57, 0.134), (57, 0.223)],
#  [(58, 0.011), (58, 0.305)],
#  [(59, 0.101), (59, 0.194)],
#  [(60, 0.098), (60, 0.234)],
#  [(61, 0.106), (61, 0.248)],
#  [(62, 0.106), (62, 0.252)],
#  [(63, 0.105), (63, 0.266)],
#  [(64, 0.094), (64, 0.275)],
#  [(65, 0.079), (65, 0.24)],
#  [(66, 0.14400000000000002), (66, 0.229)],
#  [(67, 0.091), (67, 0.232)],
#  [(68, 0.109), (68, 0.246)],
#  [(69, 0.113), (69, 0.253)],
#  [(70, 0.095), (70, 0.272)],
#  [(71, 0.043), (71, 0.315)],
#  [(72, 0.081), (72, 0.26)],
#  [(73, 0.151), (73, 0.234)],
#  [(74, 0.146), (74, 0.236)],
#  [(75, 0.073), (75, 0.241)],
#  [(76, 0.124), (76, 0.249)],
#  [(77, 0.11), (77, 0.27)],
#  [(78, 0.104), (78, 0.262)],
#  [(79, 0.135), (79, 0.24)],
#  [(80, 0.13), (80, 0.23)],
#  [(81, 0.132), (81, 0.227)],
#  [(82, 0.011), (82, 0.317)],
#  [(83, 0.123), (83, 0.228)],
#  [(84, 0.136), (84, 0.21600000000000005)],
#  [(85, 0.085), (85, 0.305)],
#  [(86, 0.126), (86, 0.252)],
#  [(87, 0.134), (87, 0.269)],
#  [(88, 0.032), (88, 0.26025)],
#  [(89, 0.129), (89, 0.266)],
#  [(90, 0.012), (90, 0.35200000000000004)],
#  [(91, 0.127), (91, 0.287)],
#  [(92, 0.08199999999999999), (92, 0.28475)],
#  [(93, 0.153), (93, 0.257)],
#  [(94, 0.096), (94, 0.244)],
#  [(95, 0.128), (95, 0.27425)],
#  [(96, 0.081), (96, 0.303)],
#  [(97, 0.087), (97, 0.322)],
#  [(98, 0.14300000000000002), (98, 0.256)],
#  [(99, 0.121), (99, 0.244)],
#  [(100, 0.107), (100, 0.297)],
#  [(101, 0.093), (101, 0.27)],
#  [(102, 0.13), (102, 0.278)],
#  [(103, 0.138), (103, 0.276)],
#  [(104, 0.13699999999999998), (104, 0.285)],
#  [(105, 0.11), (105, 0.295)],
#  [(106, 0.101), (106, 0.312)],
#  [(107, 0.118), (107, 0.272)],
#  [(108, 0.14800000000000002), (108, 0.276)],
#  [(109, 0.098), (109, 0.32299999999999995)],
#  [(110, 0.113), (110, 0.279)],
#  [(111, 0.131), (111, 0.282)],
#  [(112, 0.128), (112, 0.29100000000000004)],
#  [(113, 0.129), (113, 0.302)],
#  [(114, 0.052000000000000005), (114, 0.237)],
#  [(115, 0.16), (115, 0.265)],
#  [(116, 0.103), (116, 0.31775)],
#  [(117, 0.13), (117, 0.301)],
#  [(118, 0.107), (118, 0.303)],
#  [(119, 0.123), (119, 0.30925)],
#  [(120, 0.078), (120, 0.2705)],
#  [(121, 0.106), (121, 0.331)],
#  [(122, 0.134), (122, 0.269)],
#  [(123, 0.094), (123, 0.319)],
#  [(124, 0.119), (124, 0.305)],
#  [(125, 0.10925), (125, 0.297)],
#  [(126, 0.124), (126, 0.304)],
#  [(127, 0.151), (127, 0.278)],
#  [(128, 0.1), (128, 0.29025)],
#  [(129, 0.126), (129, 0.294)],
#  [(130, 0.155), (130, 0.293)],
#  [(131, 0.133), (131, 0.319)],
#  [(132, 0.158), (132, 0.29)],
#  [(133, 0.105), (133, 0.306)],
#  [(134, 0.1), (134, 0.312)],
#  [(135, 0.16699999999999998), (135, 0.267)],
#  [(136, 0.173), (136, 0.285)],
#  [(137, 0.16399999999999998), (137, 0.29)],
#  [(138, 0.172), (138, 0.285)],
#  [(139, 0.1015), (139, 0.294)],
#  [(140, 0.119), (140, 0.313)],
#  [(141, 0.129), (141, 0.321)],
#  [(142, 0.163), (142, 0.28800000000000003)],
#  [(143, 0.16699999999999998), (143, 0.2915)],
#  [(144, 0.121), (144, 0.31525000000000003)],
#  [(145, 0.128), (145, 0.312)],
#  [(146, 0.123), (146, 0.33925000000000005)],
#  [(147, 0.135), (147, 0.329)],
#  [(148, 0.175), (148, 0.24825)],
#  [(149, 0.115), (149, 0.337)],
#  [(150, 0.177), (150, 0.293)],
#  [(151, 0.146), (151, 0.319)],
#  [(152, 0.145), (152, 0.308)],
#  [(153, 0.136), (153, 0.27225)],
#  [(154, 0.168), (154, 0.305)],
#  [(155, 0.09), (155, 0.363)],
#  [(156, 0.15925), (156, 0.305)],
#  [(157, 0.142), (157, 0.322)],
#  [(158, 0.179), (158, 0.293)],
#  [(159, 0.16874999999999998), (159, 0.312)],
#  [(160, 0.115), (160, 0.328)],
#  [(161, 0.142), (161, 0.329)],
#  [(162, 0.133), (162, 0.339)],
#  [(163, 0.17225000000000001), (163, 0.301)],
#  [(164, 0.13699999999999998), (164, 0.287)],
#  [(165, 0.125), (165, 0.331)],
#  [(166, 0.126), (166, 0.324)],
#  [(167, 0.171), (167, 0.2955)],
#  [(168, 0.11), (168, 0.304)],
#  [(169, 0.122), (169, 0.371)],
#  [(170, 0.154), (170, 0.3)],
#  [(171, 0.15), (171, 0.327)],
#  [(172, 0.127), (172, 0.326)],
#  [(173, 0.17), (173, 0.292)],
#  [(174, 0.13), (174, 0.34600000000000003)],
#  [(175, 0.20025000000000004), (175, 0.299)],
#  [(176, 0.094), (176, 0.33925000000000005)],
#  [(177, 0.114), (177, 0.339)],
#  [(178, 0.188), (178, 0.31)],
#  [(179, 0.14400000000000002), (179, 0.336)],
#  [(180, 0.134), (180, 0.333)],
#  [(181, 0.16399999999999998), (181, 0.327)],
#  [(182, 0.146), (182, 0.322)],
#  [(183, 0.159), (183, 0.321)],
#  [(184, 0.129), (184, 0.3365)],
#  [(185, 0.113), (185, 0.355)],
#  [(186, 0.159), (186, 0.31)],
#  [(187, 0.179), (187, 0.33)],
#  [(188, 0.13625), (188, 0.34700000000000003)],
#  [(189, 0.134), (189, 0.349)],
#  [(190, 0.1235), (190, 0.362)],
#  [(191, 0.17600000000000002), (191, 0.32299999999999995)],
#  [(192, 0.16), (192, 0.326)],
#  [(193, 0.154), (193, 0.33475000000000005)],
#  [(194, 0.119), (194, 0.392)],
#  [(195, 0.141), (195, 0.3355)],
#  [(196, 0.14300000000000002), (196, 0.332)],
#  [(197, 0.126), (197, 0.353)],
#  [(198, 0.14400000000000002), (198, 0.272)],
#  [(199, 0.125), (199, 0.354)],
#  [(200, 0.145), (200, 0.32299999999999995)],
#  [(201, 0.195), (201, 0.313)],
#  [(202, 0.122), (202, 0.391)],
#  [(203, 0.163), (203, 0.339)],
#  [(204, 0.16399999999999998), (204, 0.341)],
#  [(205, 0.17), (205, 0.333)],
#  [(206, 0.136), (206, 0.32299999999999995)],
#  [(207, 0.162), (207, 0.34600000000000003)],
#  [(208, 0.123), (208, 0.363)],
#  [(209, 0.145), (209, 0.353)],
#  [(210, 0.129), (210, 0.325)],
#  [(211, 0.117), (211, 0.297)],
#  [(212, 0.166), (212, 0.343)],
#  [(213, 0.194), (213, 0.309)],
#  [(214, 0.149), (214, 0.353)],
#  [(215, 0.131), (215, 0.361)],
#  [(216, 0.198), (216, 0.3095)],
#  [(217, 0.171), (217, 0.331)],
#  [(218, 0.16399999999999998), (218, 0.344)],
#  [(219, 0.163), (219, 0.31375)],
#  [(220, 0.149), (220, 0.34974999999999995)],
#  [(221, 0.152), (221, 0.35600000000000004)],
#  [(222, 0.206), (222, 0.314)],
#  [(223, 0.174), (223, 0.338)],
#  [(224, 0.14), (224, 0.364)],
#  [(225, 0.02), (225, 0.487)],
#  [(226, 0.159), (226, 0.396)],
#  [(227, 0.17800000000000002), (227, 0.335)],
#  [(228, 0.188), (228, 0.336)],
#  [(229, 0.131), (229, 0.3365)],
#  [(230, 0.16899999999999998), (230, 0.311)],
#  [(231, 0.156), (231, 0.3625)],
#  [(232, 0.198), (232, 0.321)],
#  [(233, 0.125), (233, 0.328)],
#  [(234, 0.16674999999999998), (234, 0.35924999999999996)],
#  [(235, 0.168), (235, 0.342)],
#  [(236, 0.177), (236, 0.34600000000000003)],
#  [(237, 0.149), (237, 0.358)],
#  [(238, 0.14400000000000002), (238, 0.313)],
#  [(239, 0.131), (239, 0.374)],
#  [(240, 0.136), (240, 0.34775)],
#  [(241, 0.135), (241, 0.334)],
#  [(242, 0.173), (242, 0.317)],
#  [(243, 0.132), (243, 0.35600000000000004)],
#  [(244, 0.16825), (244, 0.36775)],
#  [(245, 0.134), (245, 0.353)],
#  [(246, 0.17800000000000002), (246, 0.362)],
#  [(247, 0.205), (247, 0.333)],
#  [(248, 0.158), (248, 0.375)],
#  [(249, 0.14800000000000002), (249, 0.374)],
#  [(250, 0.165), (250, 0.368)],
#  [(251, 0.14300000000000002), (251, 0.379)],
#  [(252, 0.172), (252, 0.35)],
#  [(253, 0.166), (253, 0.35924999999999996)],
#  [(254, 0.139), (254, 0.386)],
#  [(255, 0.18600000000000005), (255, 0.344)],
#  [(256, 0.171), (256, 0.3670000000000001)],
#  [(257, 0.162), (257, 0.29)],
#  [(258, 0.16899999999999998), (258, 0.349)],
#  [(259, 0.18), (259, 0.35700000000000004)],
#  [(260, 0.18600000000000005), (260, 0.36124999999999996)],
#  [(261, 0.17600000000000002), (261, 0.361)],
#  [(262, 0.152), (262, 0.332)],
#  [(263, 0.175), (263, 0.312)],
#  [(264, 0.15), (264, 0.365)],
#  [(265, 0.16699999999999998), (265, 0.363)],
#  [(266, 0.196), (266, 0.362)],
#  [(267, 0.197), (267, 0.34600000000000003)],
#  [(268, 0.163), (268, 0.345)],
#  [(269, 0.09575), (269, 0.42825)],
#  [(270, 0.18), (270, 0.376)],
#  [(271, 0.116), (271, 0.405)],
#  [(272, 0.191), (272, 0.35200000000000004)],
#  [(273, 0.206), (273, 0.342)],
#  [(274, 0.193), (274, 0.341)],
#  [(275, 0.174), (275, 0.35700000000000004)],
#  [(276, 0.198), (276, 0.335)],
#  [(277, 0.172), (277, 0.37)],
#  [(278, 0.223), (278, 0.328)],
#  [(279, 0.149), (279, 0.421)],
#  [(280, 0.219), (280, 0.344)],
#  [(281, 0.161), (281, 0.393)],
#  [(282, 0.133), (282, 0.428)],
#  [(283, 0.20375), (283, 0.321)],
#  [(284, 0.202), (284, 0.341)],
#  [(285, 0.158), (285, 0.39225000000000004)],
#  [(286, 0.16), (286, 0.381)],
#  [(287, 0.174), (287, 0.362)],
#  [(288, 0.195), (288, 0.361)],
#  [(289, 0.177), (289, 0.33275000000000005)],
#  [(290, 0.227), (290, 0.343)],
#  [(291, 0.165), (291, 0.403)],
#  [(292, 0.196), (292, 0.363)],
#  [(293, 0.181), (293, 0.386)],
#  [(294, 0.183), (294, 0.33425)],
#  [(295, 0.139), (295, 0.34875)],
#  [(296, 0.206), (296, 0.34825)],
#  [(297, 0.155), (297, 0.417)],
#  [(298, 0.184), (298, 0.34600000000000003)],
#  [(299, 0.2), (299, 0.366)],
#  [(300, 0.145), (300, 0.408)],
#  [(301, 0.185), (301, 0.364)],
#  [(302, 0.17800000000000002), (302, 0.36)],
#  [(303, 0.222), (303, 0.35100000000000003)],
#  [(304, 0.162), (304, 0.399)],
#  [(305, 0.182), (305, 0.37)],
#  [(306, 0.21), (306, 0.369)],
#  [(307, 0.189), (307, 0.354)],
#  [(308, 0.215), (308, 0.36)],
#  [(309, 0.205), (309, 0.353)],
#  [(310, 0.146), (310, 0.417)],
#  [(311, 0.123), (311, 0.4267500000000001)],
#  [(312, 0.153), (312, 0.39775)],
#  [(313, 0.201), (313, 0.345)],
#  [(314, 0.203), (314, 0.35200000000000004)],
#  [(315, 0.181), (315, 0.383)],
#  [(316, 0.196), (316, 0.365)],
#  [(317, 0.189), (317, 0.388)],
#  [(318, 0.212), (318, 0.344)],
#  [(319, 0.196), (319, 0.3670000000000001)],
#  [(320, 0.214), (320, 0.355)],
#  [(321, 0.185), (321, 0.3605)],
#  [(322, 0.197), (322, 0.365)],
#  [(323, 0.168), (323, 0.403)],
#  [(324, 0.17600000000000002), (324, 0.4)],
#  [(325, 0.17600000000000002), (325, 0.387)],
#  [(326, 0.183), (326, 0.361)],
#  [(327, 0.138), (327, 0.4)],
#  [(328, 0.16), (328, 0.345)],
#  [(329, 0.161), (329, 0.384)],
#  [(330, 0.136), (330, 0.408)],
#  [(331, 0.119), (331, 0.396)],
#  [(332, 0.196), (332, 0.373)],
#  [(333, 0.234), (333, 0.35)],
#  [(334, 0.16699999999999998), (334, 0.402)],
#  [(335, 0.177), (335, 0.383)],
#  [(336, 0.202), (336, 0.337)],
#  [(337, 0.19175000000000003), (337, 0.358)],
#  [(338, 0.177), (338, 0.371)],
#  [(339, 0.172), (339, 0.387)],
#  [(340, 0.128), (340, 0.38)],
#  [(341, 0.157), (341, 0.368)],
#  [(342, 0.199), (342, 0.368)],
#  [(343, 0.173), (343, 0.388)],
#  [(344, 0.21225), (344, 0.3670000000000001)],
#  [(345, 0.156), (345, 0.403)],
#  [(346, 0.187), (346, 0.402)],
#  [(347, 0.22), (347, 0.361)],
#  [(348, 0.163), (348, 0.365)],
#  [(349, 0.157), (349, 0.3670000000000001)],
#  [(350, 0.209), (350, 0.355)],
#  [(351, 0.191), (351, 0.35700000000000004)],
#  [(352, 0.166), (352, 0.395)],
#  [(353, 0.152), (353, 0.4270000000000001)],
#  [(354, 0.204), (354, 0.362)],
#  [(355, 0.177), (355, 0.391)],
#  [(356, 0.154), (356, 0.393)],
#  [(357, 0.18124999999999997), (357, 0.38275000000000003)],
#  [(358, 0.138), (358, 0.415)],
#  [(359, 0.112), (359, 0.43524999999999997)],
#  [(360, 0.201), (360, 0.406)],
#  [(361, 0.177), (361, 0.363)],
#  [(362, 0.227), (362, 0.365)],
#  [(363, 0.156), (363, 0.425)],
#  [(364, 0.142), (364, 0.46575000000000005)],
#  [(365, 0.162), (365, 0.4215)],
#  [(366, 0.17625000000000002), (366, 0.388)],
#  [(367, 0.106), (367, 0.358)],
#  [(368, 0.21), (368, 0.387)],
#  [(369, 0.242), (369, 0.35525)],
#  [(370, 0.213), (370, 0.377)],
#  [(371, 0.17800000000000002), (371, 0.411)],
#  [(372, 0.21), (372, 0.36375)],
#  [(373, 0.205), (373, 0.387)],
#  [(374, 0.196), (374, 0.388)],
#  [(375, 0.2), (375, 0.37625000000000003)],
#  [(376, 0.175), (376, 0.391)],
#  [(377, 0.14300000000000002), (377, 0.402)],
#  [(378, 0.183), (378, 0.397)],
#  [(379, 0.196), (379, 0.373)],
#  [(380, 0.011), (380, 0.513)],
#  [(381, 0.153), (381, 0.417)],
#  [(382, 0.20675), (382, 0.391)],
#  [(383, 0.198), (383, 0.406)],
#  [(384, 0.21550000000000002), (384, 0.393)],
#  [(385, 0.189), (385, 0.35)],
#  [(386, 0.17825000000000002), (386, 0.414)],
#  [(387, 0.17600000000000002), (387, 0.423)],
#  [(388, 0.212), (388, 0.377)],
#  [(389, 0.261), (389, 0.35100000000000003)],
#  [(390, 0.21600000000000005), (390, 0.364)],
#  [(391, 0.15025), (391, 0.39975000000000005)],
#  [(392, 0.199), (392, 0.38175)],
#  [(393, 0.205), (393, 0.374)],
#  [(394, 0.14400000000000002), (394, 0.374)],
#  [(395, 0.14475), (395, 0.452)],
#  [(396, 0.165), (396, 0.424)],
#  [(397, 0.188), (397, 0.376)],
#  [(398, 0.182), (398, 0.38375000000000004)],
#  [(399, 0.17800000000000002), (399, 0.385)],
#  [(400, 0.156), (400, 0.4267500000000001)],
#  [(401, 0.163), (401, 0.423)],
#  [(402, 0.18600000000000005), (402, 0.394)],
#  [(403, 0.23), (403, 0.35200000000000004)],
#  [(404, 0.198), (404, 0.394)],
#  [(405, 0.188), (405, 0.404)],
#  [(406, 0.202), (406, 0.401)],
#  [(407, 0.16899999999999998), (407, 0.4075)],
#  [(408, 0.209), (408, 0.397)],
#  [(409, 0.133), (409, 0.399)],
#  [(410, 0.19), (410, 0.377)],
#  [(411, 0.233), (411, 0.394)],
#  [(412, 0.217), (412, 0.404)],
#  [(413, 0.193), (413, 0.42524999999999996)],
#  [(414, 0.171), (414, 0.392)],
#  [(415, 0.227), (415, 0.37625000000000003)],
#  [(416, 0.18), (416, 0.41)],
#  [(417, 0.188), (417, 0.414)],
#  [(418, 0.209), (418, 0.375)],
#  [(419, 0.2205), (419, 0.395)],
#  [(420, 0.147), (420, 0.37)],
#  [(421, 0.009000000000000001), (421, 0.484)],
#  [(422, 0.171), (422, 0.428)],
#  [(423, 0.203), (423, 0.404)],
#  [(424, 0.209), (424, 0.384)],
#  [(425, 0.177), (425, 0.426)],
#  [(426, 0.197), (426, 0.413)],
#  [(427, 0.208), (427, 0.38975)],
#  [(428, 0.187), (428, 0.384)],
#  [(429, 0.188), (429, 0.382)],
#  [(430, 0.16899999999999998), (430, 0.431)],
#  [(431, 0.18), (431, 0.446)],
#  [(432, 0.248), (432, 0.365)],
#  [(433, 0.174), (433, 0.445)],
#  [(434, 0.16399999999999998), (434, 0.418)],
#  [(435, 0.129), (435, 0.464)],
#  [(436, 0.157), (436, 0.428)],
#  [(437, 0.17600000000000002), (437, 0.423)],
#  [(438, 0.219), (438, 0.405)],
#  [(439, 0.16349999999999998), (439, 0.4665)],
#  [(440, 0.226), (440, 0.39925)],
#  [(441, 0.183), (441, 0.411)],
#  [(442, 0.194), (442, 0.42)],
#  [(443, 0.188), (443, 0.42225)],
#  [(444, 0.201), (444, 0.455)],
#  [(445, 0.21), (445, 0.423)],
#  [(446, 0.18600000000000005), (446, 0.426)],
#  [(447, 0.152), (447, 0.451)],
#  [(448, 0.23825), (448, 0.391)],
#  [(449, 0.166), (449, 0.45425000000000004)],
#  [(450, 0.168), (450, 0.42)],
#  [(451, 0.125), (451, 0.442)],
#  [(452, 0.25075000000000003), (452, 0.377)],
#  [(453, 0.205), (453, 0.40075000000000005)],
#  [(454, 0.196), (454, 0.422)],
#  [(455, 0.222), (455, 0.388)],
#  [(456, 0.212), (456, 0.412)],
#  [(457, 0.223), (457, 0.414)],
#  [(458, 0.24), (458, 0.395)],
#  [(459, 0.121), (459, 0.491)],
#  [(460, 0.2), (460, 0.401)],
#  [(461, 0.229), (461, 0.4)],
#  [(462, 0.203), (462, 0.431)],
#  [(463, 0.225), (463, 0.341)],
#  [(464, 0.238), (464, 0.408)],
#  [(465, 0.14400000000000002), (465, 0.443)],
#  [(466, 0.213), (466, 0.412)],
#  [(467, 0.226), (467, 0.401)],
#  [(468, 0.161), (468, 0.46425000000000005)],
#  [(469, 0.252), (469, 0.377)],
#  [(470, 0.211), (470, 0.39)],
#  [(471, 0.157), (471, 0.453)],
#  [(472, 0.259), (472, 0.386)],
#  [(473, 0.185), (473, 0.407)],
#  [(474, 0.181), (474, 0.435)],
#  [(475, 0.18600000000000005), (475, 0.399)],
#  [(476, 0.251), (476, 0.398)],
#  [(477, 0.161), (477, 0.453)],
#  [(478, 0.249), (478, 0.396)],
#  [(479, 0.253), (479, 0.373)],
#  [(480, 0.25), (480, 0.398)],
#  [(481, 0.221), (481, 0.424)],
#  [(482, 0.222), (482, 0.39)],
#  [(483, 0.188), (483, 0.457)],
#  [(484, 0.217), (484, 0.434)],
#  [(485, 0.166), (485, 0.475)],
#  [(486, 0.259), (486, 0.378)],
#  [(487, 0.238), (487, 0.406)],
#  [(488, 0.21175), (488, 0.42025)],
#  [(489, 0.218), (489, 0.449)],
#  [(490, 0.227), (490, 0.41)],
#  [(491, 0.205), (491, 0.417)],
#  [(492, 0.163), (492, 0.457)],
#  [(493, 0.17800000000000002), (493, 0.42175)],
#  [(494, 0.245), (494, 0.398)],
#  [(495, 0.215), (495, 0.411)],
#  [(496, 0.209), (496, 0.41225)],
#  [(497, 0.177), (497, 0.476)],
#  [(498, 0.1775), (498, 0.425)],
#  [(499, 0.208), (499, 0.41625)],
#  [(500, 0.234), (500, 0.4)],
#  [(501, 0.219), (501, 0.41)],
#  [(502, 0.157), (502, 0.417)],
#  [(503, 0.174), (503, 0.47)],
#  [(504, 0.246), (504, 0.387)],
#  [(505, 0.168), (505, 0.455)],
#  [(506, 0.25), (506, 0.398)],
#  [(507, 0.011), (507, 0.574)],
#  [(508, 0.18), (508, 0.446)],
#  [(509, 0.26), (509, 0.4)],
#  [(510, 0.16899999999999998), (510, 0.478)],
#  [(511, 0.189), (511, 0.414)],
#  [(512, 0.191), (512, 0.429)],
#  [(513, 0.202), (513, 0.414)],
#  [(514, 0.141), (514, 0.45975000000000005)],
#  [(515, 0.23975), (515, 0.418)],
#  [(516, 0.208), (516, 0.426)],
#  [(517, 0.199), (517, 0.435)],
#  [(518, 0.198), (518, 0.44025000000000003)],
#  [(519, 0.234), (519, 0.409)],
#  [(520, 0.187), (520, 0.443)],
#  [(521, 0.159), (521, 0.48)],
#  [(522, 0.199), (522, 0.47)],
#  [(523, 0.255), (523, 0.407)],
#  [(524, 0.17), (524, 0.466)],
#  [(525, 0.209), (525, 0.4415)],
#  [(526, 0.154), (526, 0.4555)],
#  [(527, 0.165), (527, 0.458)],
#  [(528, 0.191), (528, 0.411)],
#  [(529, 0.281), (529, 0.388)],
#  [(530, 0.266), (530, 0.383)],
#  [(531, 0.23675), (531, 0.417)],
#  [(532, 0.227), (532, 0.442)],
#  [(533, 0.227), (533, 0.428)],
#  [(534, 0.211), (534, 0.422)],
#  [(535, 0.229), (535, 0.428)],
#  [(536, 0.19), (536, 0.471)],
#  [(537, 0.212), (537, 0.42975)],
#  [(538, 0.213), (538, 0.393)],
#  [(539, 0.215), (539, 0.446)],
#  [(540, 0.18), (540, 0.467)],
#  [(541, 0.208), (541, 0.44925)],
#  [(542, 0.275), (542, 0.38375000000000004)],
#  [(543, 0.194), (543, 0.455)],
#  [(544, 0.204), (544, 0.435)],
#  [(545, 0.213), (545, 0.413)],
#  [(546, 0.211), (546, 0.451)],
#  [(547, 0.237), (547, 0.446)],
#  [(548, 0.205), (548, 0.45)],
#  [(549, 0.207), (549, 0.416)],
#  [(550, 0.215), (550, 0.45)],
#  [(551, 0.155), (551, 0.4565)],
#  [(552, 0.214), (552, 0.44)],
#  [(553, 0.246), (553, 0.43324999999999997)],
#  [(554, 0.232), (554, 0.442)],
#  [(555, 0.138), (555, 0.464)],
#  [(556, 0.194), (556, 0.434)],
#  [(557, 0.212), (557, 0.456)],
#  [(558, 0.202), (558, 0.446)],
#  [(559, 0.29025), (559, 0.403)],
#  [(560, 0.225), (560, 0.405)],
#  [(561, 0.21225), (561, 0.456)],
#  [(562, 0.224), (562, 0.441)],
#  [(563, 0.209), (563, 0.446)],
#  [(564, 0.242), (564, 0.4322500000000001)],
#  [(565, 0.206), (565, 0.451)],
#  [(566, 0.244), (566, 0.441)],
#  [(567, 0.251), (567, 0.417)],
#  [(568, 0.204), (568, 0.489)],
#  [(569, 0.237), (569, 0.4270000000000001)],
#  [(570, 0.2), (570, 0.426)],
#  [(571, 0.259), (571, 0.424)],
#  [(572, 0.158), (572, 0.521)],
#  [(573, 0.188), (573, 0.488)],
#  [(574, 0.17600000000000002), (574, 0.479)],
#  [(575, 0.18175000000000002), (575, 0.468)],
#  [(576, 0.228), (576, 0.453)],
#  [(577, 0.273), (577, 0.411)],
#  [(578, 0.147), (578, 0.425)],
#  [(579, 0.207), (579, 0.419)],
#  [(580, 0.15), (580, 0.495)],
#  [(581, 0.17800000000000002), (581, 0.47624999999999995)],
#  [(582, 0.252), (582, 0.453)],
#  [(583, 0.179), (583, 0.4885)],
#  [(584, 0.18274999999999997), (584, 0.491)],
#  [(585, 0.238), (585, 0.457)],
#  [(586, 0.247), (586, 0.4270000000000001)],
#  [(587, 0.245), (587, 0.419)],
#  [(588, 0.222), (588, 0.455)],
#  [(589, 0.117), (589, 0.526)],
#  [(590, 0.2), (590, 0.467)],
#  [(591, 0.209), (591, 0.47824999999999995)],
#  [(592, 0.26), (592, 0.43)],
#  [(593, 0.28800000000000003), (593, 0.408)],
#  [(594, 0.246), (594, 0.413)],
#  [(595, 0.206), (595, 0.482)],
#  [(596, 0.26), (596, 0.4525)],
#  [(597, 0.181), (597, 0.487)],
#  [(598, 0.238), (598, 0.433)],
#  [(599, 0.157), (599, 0.496)],
#  [(600, 0.243), (600, 0.456)],
#  [(601, 0.244), (601, 0.448)],
#  [(602, 0.05), (602, 0.26)],
#  [(603, 0.203), (603, 0.534)],
#  [(604, 0.195), (604, 0.493)],
#  [(605, 0.218), (605, 0.49)],
#  [(606, 0.16225), (606, 0.39375)],
#  [(607, 0.1735), (607, 0.506)],
#  [(608, 0.272), (608, 0.429)],
#  [(609, 0.171), (609, 0.499)],
#  [(610, 0.261), (610, 0.42575)],
#  [(611, 0.208), (611, 0.438)],
#  [(612, 0.198), (612, 0.48)],
#  [(613, 0.2), (613, 0.452)],
#  [(614, 0.229), (614, 0.446)],
#  [(615, 0.155), (615, 0.465)],
#  [(616, 0.237), (616, 0.445)],
#  [(617, 0.182), (617, 0.491)],
#  [(618, 0.229), (618, 0.431)],
#  [(619, 0.194), (619, 0.434)],
#  [(620, 0.202), (620, 0.481)],
#  [(621, 0.223), (621, 0.461)],
#  [(622, 0.153), (622, 0.51625)],
#  [(623, 0.274), (623, 0.412)],
#  [(624, 0.171), (624, 0.446)],
#  [(625, 0.25), (625, 0.461)],
#  [(626, 0.29), (626, 0.404)],
#  [(627, 0.242), (627, 0.452)],
#  [(628, 0.209), (628, 0.476)],
#  [(629, 0.16), (629, 0.529)],
#  [(630, 0.271), (630, 0.43)],
#  [(631, 0.26525), (631, 0.435)],
#  [(632, 0.192), (632, 0.435)],
#  [(633, 0.165), (633, 0.50025)],
#  [(634, 0.249), (634, 0.459)],
#  [(635, 0.16), (635, 0.441)],
#  [(636, 0.13925), (636, 0.488)],
#  [(637, 0.175), (637, 0.477)],
#  [(638, 0.244), (638, 0.469)],
#  [(639, 0.257), (639, 0.431)],
#  [(640, 0.206), (640, 0.521)],
#  [(641, 0.227), (641, 0.439)],
#  [(642, 0.268), (642, 0.425)],
#  [(643, 0.238), (643, 0.475)],
#  [(644, 0.23675), (644, 0.453)],
#  [(645, 0.21), (645, 0.501)],
#  [(646, 0.131), (646, 0.524)],
#  [(647, 0.236), (647, 0.476)],
#  [(648, 0.26), (648, 0.45)],
#  [(649, 0.191), (649, 0.466)],
#  [(650, 0.237), (650, 0.459)],
#  [(651, 0.304), (651, 0.42)],
#  [(652, 0.218), (652, 0.441)],
#  [(653, 0.226), (653, 0.462)],
#  [(654, 0.239), (654, 0.486)],
#  [(655, 0.189), (655, 0.4320000000000001)],
#  [(656, 0.29100000000000004), (656, 0.438)],
#  [(657, 0.206), (657, 0.463)],
#  [(658, 0.243), (658, 0.493)],
#  [(659, 0.207), (659, 0.483)],
#  [(660, 0.276), (660, 0.416)],
#  [(661, 0.196), (661, 0.53375)],
#  [(662, 0.247), (662, 0.45825000000000005)],
#  [(663, 0.284), (663, 0.441)],
#  [(664, 0.229), (664, 0.454)],
#  [(665, 0.208), (665, 0.496)],
#  [(666, 0.22), (666, 0.436)],
#  [(667, 0.181), (667, 0.515)],
#  [(668, 0.20825), (668, 0.469)],
#  [(669, 0.196), (669, 0.54275)],
#  [(670, 0.256), (670, 0.466)],
#  [(671, 0.269), (671, 0.46)],
#  [(672, 0.272), (672, 0.447)],
#  [(673, 0.203), (673, 0.491)],
#  [(674, 0.214), (674, 0.5)],
#  [(675, 0.255), (675, 0.452)],
#  [(676, 0.226), (676, 0.43)],
#  [(677, 0.22975), (677, 0.487)],
#  [(678, 0.125), (678, 0.7067500000000001)],
#  [(679, 0.18274999999999997), (679, 0.52725)],
#  [(680, 0.266), (680, 0.453)],
#  [(681, 0.17), (681, 0.552)],
#  [(682, 0.213), (682, 0.482)],
#  [(683, 0.117), (683, 0.643)],
#  [(684, 0.197), (684, 0.488)],
#  [(685, 0.202), (685, 0.459)],
#  [(686, 0.238), (686, 0.441)],
#  [(687, 0.228), (687, 0.498)],
#  [(688, 0.26475000000000004), (688, 0.442)],
#  [(689, 0.258), (689, 0.46925)],
#  [(690, 0.218), (690, 0.45225000000000004)],
#  [(691, 0.241), (691, 0.491)],
#  [(692, 0.174), (692, 0.532)],
#  [(693, 0.255), (693, 0.47675)],
#  [(694, 0.25), (694, 0.425)],
#  [(695, 0.214), (695, 0.5)],
#  [(696, 0.237), (696, 0.449)],
#  [(697, 0.229), (697, 0.455)],
#  [(698, 0.24), (698, 0.471)],
#  [(699, 0.242), (699, 0.48)],
#  [(700, 0.263), (700, 0.4372500000000001)],
#  [(701, 0.225), (701, 0.563)],
#  [(702, 0.21600000000000005), (702, 0.506)],
#  [(703, 0.249), (703, 0.495)],
#  [(704, 0.226), (704, 0.426)],
#  [(705, 0.272), (705, 0.463)],
#  [(706, 0.28800000000000003), (706, 0.452)],
#  [(707, 0.256), (707, 0.473)],
#  [(708, 0.171), (708, 0.454)],
#  [(709, 0.213), (709, 0.48925)],
#  [(710, 0.196), (710, 0.5305)],
#  [(711, 0.318), (711, 0.442)],
#  [(712, 0.181), (712, 0.491)],
#  [(713, 0.246), (713, 0.51)],
#  [(714, 0.194), (714, 0.514)],
#  [(715, 0.188), (715, 0.527)],
#  [(716, 0.172), (716, 0.5760000000000001)],
#  [(717, 0.244), (717, 0.454)],
#  [(718, 0.206), (718, 0.532)],
#  [(719, 0.182), (719, 0.545)],
#  [(720, 0.266), (720, 0.4875)],
#  [(721, 0.287), (721, 0.45375000000000004)],
#  [(722, 0.261), (722, 0.478)],
#  [(723, 0.232), (723, 0.4970000000000001)],
#  [(724, 0.228), (724, 0.486)],
#  [(725, 0.14800000000000002), (725, 0.60825)],
#  [(726, 0.223), (726, 0.514)],
#  [(727, 0.131), (727, 0.589)],
#  [(728, 0.247), (728, 0.4920000000000001)],
#  [(729, 0.208), (729, 0.421)],
#  [(730, 0.23), (730, 0.528)],
#  [(731, 0.212), (731, 0.498)],
#  [(732, 0.231), (732, 0.47275)],
#  [(733, 0.25), (733, 0.499)],
#  [(734, 0.232), (734, 0.4675)],
#  [(735, 0.264), (735, 0.47)],
#  [(736, 0.28625), (736, 0.436)],
#  [(737, 0.196), (737, 0.539)],
#  [(738, 0.15), (738, 0.56)],
#  [(739, 0.245), (739, 0.488)],
#  [(740, 0.21475), (740, 0.513)],
#  [(741, 0.258), (741, 0.459)],
#  [(742, 0.243), (742, 0.483)],
#  [(743, 0.207), (743, 0.50475)],
#  [(744, 0.266), (744, 0.494)],
#  [(745, 0.241), (745, 0.511)],
#  [(746, 0.242), (746, 0.475)],
#  [(747, 0.221), (747, 0.494)],
#  [(748, 0.199), (748, 0.54)],
#  [(749, 0.197), (749, 0.569)],
#  [(750, 0.206), (750, 0.483)],
#  [(751, 0.28600000000000003), (751, 0.471)],
#  [(752, 0.251), (752, 0.502)],
#  [(753, 0.243), (753, 0.494)],
#  [(754, 0.26775000000000004), (754, 0.469)],
#  [(755, 0.202), (755, 0.50275)],
#  [(756, 0.22275), (756, 0.505)],
#  [(757, 0.275), (757, 0.477)],
#  [(758, 0.234), (758, 0.534)],
#  [(759, 0.314), (759, 0.438)],
#  [(760, 0.159), (760, 0.505)],
#  [(761, 0.267), (761, 0.485)],
#  [(762, 0.201), (762, 0.477)],
#  [(763, 0.203), (763, 0.5315000000000001)],
#  [(764, 0.236), (764, 0.462)],
#  [(765, 0.263), (765, 0.453)],
#  [(766, 0.28600000000000003), (766, 0.461)],
#  [(767, 0.232), (767, 0.505)],
#  [(768, 0.25), (768, 0.502)],
#  [(769, 0.221), (769, 0.515)],
#  [(770, 0.273), (770, 0.483)],
#  [(771, 0.213), (771, 0.546)],
#  [(772, 0.253), (772, 0.454)],
#  [(773, 0.259), (773, 0.491)],
#  [(774, 0.254), (774, 0.496)],
#  [(775, 0.278), (775, 0.484)],
#  [(776, 0.28600000000000003), (776, 0.493)],
#  [(777, 0.229), (777, 0.53)],
#  [(778, 0.2), (778, 0.534)],
#  [(779, 0.312), (779, 0.45025000000000004)],
#  [(780, 0.207), (780, 0.5397500000000001)],
#  [(781, 0.252), (781, 0.457)],
#  [(782, 0.242), (782, 0.508)],
#  [(783, 0.316), (783, 0.46475)],
#  [(784, 0.196), (784, 0.54)],
#  [(785, 0.203), (785, 0.539)],
#  [(786, 0.223), (786, 0.512)],
#  [(787, 0.245), (787, 0.499)],
#  [(788, 0.24225), (788, 0.461)],
#  [(789, 0.28), (789, 0.48)],
#  [(790, 0.307), (790, 0.463)],
#  [(791, 0.228), (791, 0.5)],
#  [(792, 0.209), (792, 0.535)],
#  [(793, 0.237), (793, 0.5155000000000001)],
#  [(794, 0.266), (794, 0.465)],
#  [(795, 0.271), (795, 0.493)],
#  [(796, 0.304), (796, 0.485)],
#  [(797, 0.25025), (797, 0.512)],
#  [(798, 0.269), (798, 0.51125)],
#  [(799, 0.318), (799, 0.457)],
#  [(800, 0.255), (800, 0.462)],
#  [(801, 0.224), (801, 0.495)],
#  [(802, 0.197), (802, 0.5379999999999999)],
#  [(803, 0.201), (803, 0.552)],
#  [(804, 0.256), (804, 0.534)],
#  [(805, 0.247), (805, 0.477)],
#  [(806, 0.202), (806, 0.56)],
#  [(807, 0.22), (807, 0.52475)],
#  [(808, 0.225), (808, 0.536)],
#  [(809, 0.266), (809, 0.475)],
#  [(810, 0.274), (810, 0.496)],
#  [(811, 0.259), (811, 0.507)],
#  [(812, 0.236), (812, 0.512)],
#  [(813, 0.222), (813, 0.527)],
#  [(814, 0.241), (814, 0.5255000000000001)],
#  [(815, 0.244), (815, 0.507)],
#  [(816, 0.276), (816, 0.476)],
#  [(817, 0.209), (817, 0.58)],
#  [(818, 0.204), (818, 0.534)],
#  [(819, 0.275), (819, 0.4970000000000001)],
#  [(820, 0.229), (820, 0.534)],
#  [(821, 0.23875), (821, 0.484)],
#  [(822, 0.20575), (822, 0.5479999999999999)],
#  [(823, 0.313), (823, 0.478)],
#  [(824, 0.2), (824, 0.52425)],
#  [(825, 0.281), (825, 0.505)],
#  [(826, 0.236), (826, 0.5365)],
#  [(827, 0.198), (827, 0.59575)],
#  [(828, 0.24175), (828, 0.5479999999999999)],
#  [(829, 0.244), (829, 0.509)],
#  [(830, 0.311), (830, 0.488)],
#  [(831, 0.211), (831, 0.493)],
#  [(832, 0.25), (832, 0.514)],
#  [(833, 0.275), (833, 0.508)],
#  [(834, 0.237), (834, 0.52275)],
#  [(835, 0.295), (835, 0.502)],
#  [(836, 0.252), (836, 0.526)],
#  [(837, 0.329), (837, 0.466)],
#  [(838, 0.289), (838, 0.467)],
#  [(839, 0.229), (839, 0.59)],
#  [(840, 0.2), (840, 0.586)],
#  [(841, 0.325), (841, 0.481)],
#  [(842, 0.294), (842, 0.499)],
#  [(843, 0.254), (843, 0.484)],
#  [(844, 0.253), (844, 0.56)],
#  [(845, 0.298), (845, 0.4920000000000001)],
#  [(846, 0.255), (846, 0.52675)],
#  [(847, 0.28), (847, 0.514)],
#  [(848, 0.238), (848, 0.531)],
#  [(849, 0.311), (849, 0.483)],
#  [(850, 0.33825), (850, 0.479)],
#  [(851, 0.258), (851, 0.512)],
#  [(852, 0.173), (852, 0.563)],
#  [(853, 0.209), (853, 0.485)],
#  [(854, 0.343), (854, 0.481)],
#  [(855, 0.282), (855, 0.517)],
#  [(856, 0.276), (856, 0.476)],
#  [(857, 0.208), (857, 0.6054999999999999)],
#  [(858, 0.27), (858, 0.52)],
#  [(859, 0.28800000000000003), (859, 0.458)],
#  [(860, 0.328), (860, 0.482)],
#  [(861, 0.284), (861, 0.507)],
#  [(862, 0.28925), (862, 0.50275)],
#  [(863, 0.206), (863, 0.627)],
#  [(864, 0.204), (864, 0.591)],
#  [(865, 0.255), (865, 0.529)],
#  [(866, 0.285), (866, 0.466)],
#  [(867, 0.267), (867, 0.523)],
#  [(868, 0.192), (868, 0.53275)],
#  [(869, 0.321), (869, 0.481)],
#  [(870, 0.321), (870, 0.50025)],
#  [(871, 0.232), (871, 0.541)],
#  [(872, 0.28600000000000003), (872, 0.485)],
#  [(873, 0.28800000000000003), (873, 0.5125)],
#  [(874, 0.254), (874, 0.513)],
#  [(875, 0.214), (875, 0.53025)],
#  [(876, 0.24575), (876, 0.53)],
#  [(877, 0.263), (877, 0.561)],
#  [(878, 0.257), (878, 0.5379999999999999)],
#  [(879, 0.271), (879, 0.541)],
#  [(880, 0.195), (880, 0.578)],
#  [(881, 0.28800000000000003), (881, 0.498)],
#  [(882, 0.287), (882, 0.546)],
#  [(883, 0.28800000000000003), (883, 0.51375)],
#  [(884, 0.328), (884, 0.486)],
#  [(885, 0.273), (885, 0.518)],
#  [(886, 0.293), (886, 0.532)],
#  [(887, 0.265), (887, 0.574)],
#  [(888, 0.28600000000000003), (888, 0.506)],
#  [(889, 0.175), (889, 0.5517500000000001)],
#  [(890, 0.238), (890, 0.569)],
#  [(891, 0.228), (891, 0.507)],
#  [(892, 0.315), (892, 0.504)],
#  [(893, 0.322), (893, 0.507)],
#  [(894, 0.271), (894, 0.59425)],
#  [(895, 0.278), (895, 0.547)],
#  [(896, 0.227), (896, 0.55)],
#  [(897, 0.28300000000000003), (897, 0.4335)],
#  [(898, 0.265), (898, 0.584)],
#  [(899, 0.262), (899, 0.53)],
#  [(900, 0.301), (900, 0.5379999999999999)],
#  [(901, 0.298), (901, 0.504)],
#  [(902, 0.31575), (902, 0.481)],
#  [(903, 0.322), (903, 0.4970000000000001)],
#  [(904, 0.258), (904, 0.569)],
#  [(905, 0.241), (905, 0.55)],
#  [(906, 0.2), (906, 0.614)],
#  [(907, 0.295), (907, 0.525)],
#  [(908, 0.23975), (908, 0.509)],
#  [(909, 0.302), (909, 0.511)],
#  [(910, 0.193), (910, 0.343)],
#  [(911, 0.203), (911, 0.56)],
#  [(912, 0.319), (912, 0.524)],
#  [(913, 0.237), (913, 0.564)],
#  [(914, 0.29100000000000004), (914, 0.53875)],
#  [(915, 0.279), (915, 0.529)],
#  [(916, 0.277), (916, 0.5395000000000001)],
#  [(917, 0.253), (917, 0.607)],
#  [(918, 0.242), (918, 0.545)],
#  [(919, 0.285), (919, 0.561)],
#  [(920, 0.259), (920, 0.517)],
#  [(921, 0.274), (921, 0.517)],
#  [(922, 0.264), (922, 0.5055000000000001)],
#  [(923, 0.262), (923, 0.584)],
#  [(924, 0.247), (924, 0.528)],
#  [(925, 0.278), (925, 0.5625)],
#  [(926, 0.25575000000000003), (926, 0.55225)],
#  [(927, 0.343), (927, 0.495)],
#  [(928, 0.16), (928, 0.643)],
#  [(929, 0.297), (929, 0.55)],
#  [(930, 0.1375), (930, 0.62275)],
#  [(931, 0.24275), (931, 0.60225)],
#  [(932, 0.237), (932, 0.505)],
#  [(933, 0.245), (933, 0.5567500000000001)],
#  [(934, 0.29600000000000004), (934, 0.551)],
#  [(935, 0.36), (935, 0.51725)],
#  [(936, 0.28), (936, 0.5539999999999999)],
#  [(937, 0.22325), (937, 0.526)],
#  [(938, 0.29100000000000004), (938, 0.565)],
#  [(939, 0.344), (939, 0.4970000000000001)],
#  [(940, 0.302), (940, 0.555)],
#  [(941, 0.215), (941, 0.607)],
#  [(942, 0.271), (942, 0.59475)],
#  [(943, 0.263), (943, 0.5660000000000001)],
#  [(944, 0.299), (944, 0.5529999999999999)],
#  [(945, 0.287), (945, 0.55)],
#  [(946, 0.341), (946, 0.515)],
#  [(947, 0.28800000000000003), (947, 0.578)],
#  [(948, 0.248), (948, 0.59675)],
#  [(949, 0.292), (949, 0.521)],
#  [(950, 0.324), (950, 0.547)],
#  [(951, 0.3), (951, 0.55)],
#  [(952, 0.242), (952, 0.5495)],
#  [(953, 0.293), (953, 0.5479999999999999)],
#  [(954, 0.273), (954, 0.53)],
#  [(955, 0.175), (955, 0.483)],
#  [(956, 0.34125000000000005), (956, 0.519)],
#  [(957, 0.321), (957, 0.54325)],
#  [(958, 0.3), (958, 0.568)],
#  [(959, 0.28), (959, 0.5579999999999999)],
#  [(960, 0.23375), (960, 0.585)],
#  [(961, 0.345), (961, 0.5579999999999999)],
#  [(962, 0.269), (962, 0.598)],
#  [(963, 0.25), (963, 0.60925)],
#  [(964, 0.277), (964, 0.57)],
#  [(965, 0.285), (965, 0.588)],
#  [(966, 0.284), (966, 0.5660000000000001)],
#  [(967, 0.271), (967, 0.5870000000000001)],
#  [(968, 0.28625), (968, 0.568)],
#  [(969, 0.34700000000000003), (969, 0.531)],
#  [(970, 0.333), (970, 0.531)],
#  [(971, 0.298), (971, 0.544)],
#  [(972, 0.28300000000000003), (972, 0.5770000000000001)],
#  [(973, 0.293), (973, 0.522)],
#  [(974, 0.307), (974, 0.5397500000000001)],
#  [(975, 0.227), (975, 0.634)],
#  [(976, 0.255), (976, 0.5532499999999999)],
#  [(977, 0.318), (977, 0.541)],
#  [(978, 0.3), (978, 0.569)],
#  [(979, 0.235), (979, 0.55)],
#  [(980, 0.284), (980, 0.5589999999999999)],
#  [(981, 0.304), (981, 0.5670000000000001)],
#  [(982, 0.28), (982, 0.5579999999999999)],
#  [(983, 0.237), (983, 0.622)],
#  [(984, 0.35700000000000004), (984, 0.523)],
#  [(985, 0.317), (985, 0.565)],
#  [(986, 0.29), (986, 0.597)],
#  [(987, 0.312), (987, 0.5760000000000001)],
#  [(988, 0.29600000000000004), (988, 0.574)],
#  [(989, 0.227), (989, 0.597)],
#  [(990, 0.044), (990, 0.6859999999999999)],
#  [(991, 0.268), (991, 0.589)],
#  [(992, 0.28800000000000003), (992, 0.573)],
#  [(993, 0.279), (993, 0.486)],
#  [(994, 0.292), (994, 0.5329999999999999)],
#  [(995, 0.261), (995, 0.66575)],
#  [(996, 0.28600000000000003), (996, 0.594)],
#  [(997, 0.297), (997, 0.5820000000000001)],
#  [(998, 0.326), (998, 0.5435)],
#  [(999, 0.233), (999, 0.613)],
#  ...]

# %%
len(lines)
# Out:
# 1292

# %%
from matplotlib.collections import  LineCollection

fig, ax = plt.subplots(figsize=(40,60))

plt.scatter(minmax_train['mID'], minmax_train['mean'], c="r",s=50)

lc = LineCollection(lines, colors=['grey'])
ax.set_xlim(0, 1292)
ax.set_ylim(0,13)
ax.add_collection(lc)
plt.yticks(np.arange(0, 13, step=0.2),fontsize=18)
plt.title("25%-75% IQR & mean pattern", fontsize=32)
plt.show()

# %% [markdown]
# #### 2. multiple Time Series plot

# %%
countsorted = pd.DataFrame(stats.T.get("count")).sort_values(by="count")

# IQR +- 1.5 IQR counts exclude
stat_counts = countsorted.describe()
first = stat_counts.loc["25%"]
third = stat_counts.loc["75%"]
print("데이터 개수 통계 \n1st Q: %.2f, 3rd Q: %.2f \nIQR: %.2f ~ %.2f" 
      %(first,third, first-1.5*(third-first), third+1.5*(third-first)))
# Out:
# 데이터 개수 통계
# 1st Q: 3037.00, 3rd Q: 3067.00
# IQR: 2992.00 ~ 3112.00

# %%
# over 25% quartile
over = countsorted[countsorted['count'] > 3037.00]
overid = over.index

# Index sorted for data over 25% quartile
overid
# Out:
# Index(['X1196', 'X827', 'X1473', 'X648', 'X660', 'X641', 'X678', 'X694',
#        'X1261', 'X844',
#        ...
#        'X114', 'X113', 'X99', 'X83', 'X77', 'X101', 'X93', 'X89', 'X69',
#        'X90'],
#       dtype='object', length=928)

# %%
train_t = train.T
sorted_bycount = train_t.loc[overid]

# %%
# 원래 sorteed_bycount.iloc[].plot() 을 사용하여 몇 개의 샘플을 한 번에 timeseries 그래프로 나타내고자 하였으나
# 메모리 등의 부족으로 코드를 run할 수가 없음. 

# sorted_bycount.iloc[0].plot()

# %% [markdown]
# * 요일, 시간대 및 휴일 구분
# * 기상 데이터 및 평균 전력 데이터 가져오기
# * 클러스터링 해보기
