# %%
import pandas as pd

# %%
original = pd.read_csv("result/01.시간별평균.csv",index_col=0)
original.head(2)
# Out:
#           X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  \
# meter_id
# X5            6.853865      6.662421      6.535229      6.450732
# X7            1.258811      1.275497      1.289773      1.301985
#
#           X2018_7_1_5h  X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  \
# meter_id
# X5            6.394607      6.357335      6.332590      6.316171
# X7            1.312433      1.321371      1.329018      1.335560
#
#           X2018_7_1_9h  X2018_7_1_10h  ...  X2018_7_6_d  X2018_7_7_d  \
# meter_id                               ...
# X5            6.305283       6.298071  ...   151.158682   151.165311
# X7            1.341157       1.345945  ...    40.379061    40.218087
#
#           X2018_7_8_d  X2018_7_9_d  X2018_7_10_d    X2018_7_m    X2018_8_m  \
# meter_id
# X5         151.188368   151.219685    151.255155  4700.315536  4734.280821
# X7          40.145692    40.118418     40.114128  1268.281828  1265.220143
#
#             X2018_9_m   X2018_10_m   X2018_11_m
# ...

# %%
first50 = pd.read_csv("result/first50_Hrly.csv", index_col=0)
first50 = first50.set_index(first50.meter_id)
first50 = first50.drop(columns='meter_id')
first50.head(2)
# Out:
#           X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  \
# meter_id
# X26           1.244760       1.25503      1.255030      1.255030
# X303          0.421852       0.48902      0.451373      0.459667
#
#           X2018_7_1_5h  X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  \
# meter_id
# X26           1.416628      1.433000      1.427988      1.431365
# X303          0.466374      0.456564      0.436876      0.434481
#
#           X2018_7_1_9h  X2018_7_1_10h  ...  X2018_7_1_15h  X2018_7_1_16h  \
# meter_id                               ...
# X26           1.444609       1.427246  ...       1.427246       1.441694
# X303          0.441006       0.523824  ...       0.719597       0.764629
#
#           X2018_7_1_17h  X2018_7_1_18h  X2018_7_1_19h  X2018_7_1_20h  \
# meter_id
# X26            1.432485       1.444609       1.444609       1.444609
# X303           0.760534       0.752615       0.730338       0.708196
#
# ...

# %%
new = original.copy()
for i in new.index:
    if i in first50.index:
        for k in range(24):
            new.loc[i][k] = first50.loc[i][k]
    else:
        continue
new
# Out:
#           X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  \
# meter_id
# X5            6.853865      6.662421      6.535229      6.450732
# X7            1.258811      1.275497      1.289773      1.301985
# X10           2.166754      2.297002      2.408626      2.504290
# X16           3.716997      3.962427      4.046752      3.962427
# X18           2.500810      2.510078      2.517351      2.523060
# ...                ...           ...           ...           ...
# X468          0.218497      0.222978      0.225694      0.227340
# X470          0.378563      0.378393      0.378284      0.378215
# X472          0.299721      0.282411      0.273176      0.268250
# X473          0.230856      0.220474      0.218190      0.217690
# X481          0.254965      0.257304      0.258989      0.260203
#
#           X2018_7_1_5h  X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  \
# meter_id
# X5            6.394607      6.357335      6.332590      6.316171
# ...

# %%
new.to_csv("result/06.first50Changed.csv")

# %%
second50 = pd.read_csv("result/50_100_Hrly.csv", index_col=0)
second50 = second50.set_index(second50.meter_id)
second50 = second50.drop(columns='meter_id')
second50.head(2)
# Out:
#           X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  \
# meter_id
# X7            1.324154      1.392672      1.362448      1.324154
# X263          0.428933      0.343173      0.225675      0.217511
#
#           X2018_7_1_5h  X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  \
# meter_id
# X7            1.392672      1.368409      1.362448      1.429912
# X263          0.179412      0.189693      0.179750      0.189356
#
#           X2018_7_1_9h  X2018_7_1_10h  ...  X2018_7_1_15h  X2018_7_1_16h  \
# meter_id                               ...
# X7            1.432966       1.432966  ...       1.396421       1.396421
# X263          0.268932       0.356352  ...       0.359843       0.359843
#
#           X2018_7_1_17h  X2018_7_1_18h  X2018_7_1_19h  X2018_7_1_20h  \
# meter_id
# X7             1.396421       1.396421       1.396421       1.392672
# X263           0.362673       0.362673       0.390666       0.396449
#
# ...

# %%
new2 = new.copy()
for i in new2.index:
    if i in second50.index:
        for k in range(24):
            new2.loc[i][k] = second50.loc[i][k]
    else:
        continue
new2
# Out:
#           X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  \
# meter_id
# X5            6.443345      6.443345      6.172174      6.140686
# X7            1.324154      1.392672      1.362448      1.324154
# X10           2.613603      3.816313      3.816313      3.925877
# X16           3.716997      3.962427      4.046752      3.962427
# X18           2.570956      2.557992      2.561768      2.560509
# ...                ...           ...           ...           ...
# X468          0.197778      0.188929      0.140019      0.188929
# X470          0.378563      0.378393      0.378284      0.378215
# X472          0.299721      0.282411      0.273176      0.268250
# X473          0.230856      0.220474      0.218190      0.217690
# X481          0.246865      0.254876      0.237830      0.255963
#
#           X2018_7_1_5h  X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  \
# meter_id
# X5            6.110991      6.008211      5.978516      6.090530
# ...

# %%
new2.to_csv("result/06_1.100Changed.csv")

# %%
_150_180 = pd.read_csv("result/150_180_Hrly.csv", index_col=0)
_150_180 = _150_180.set_index(_150_180.meter_id)
_150_180 = _150_180.drop(columns='meter_id')
_150_180.head(2)
# Out:
#           X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  \
# meter_id
# X449          0.183516      0.205738      0.152644      0.194860
# X383          0.206339      0.206505      0.131980      0.144445
#
#           X2018_7_1_5h  X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  \
# meter_id
# X449          0.194162      0.218955      0.197295      0.241018
# X383          0.144859      0.137307      0.127700      0.182467
#
#           X2018_7_1_9h  X2018_7_1_10h  ...  X2018_7_1_15h  X2018_7_1_16h  \
# meter_id                               ...
# X449          0.322658       0.441546  ...       0.346424       0.319282
# X383          0.282157       0.358006  ...       0.256502       0.248147
#
#           X2018_7_1_17h  X2018_7_1_18h  X2018_7_1_19h  X2018_7_1_20h  \
# meter_id
# X449           0.330835       0.341104       0.416396       0.439795
# X383           0.246770       0.249144       0.239392       0.313140
#
# ...

# %%
new3 = new2.copy()
for i in new3.index:
    if i in _150_180.index:
        for k in range(24):
            new3.loc[i][k] = _150_180.loc[i][k]
    else:
        continue
new3
# Out:
#           X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  \
# meter_id
# X5            6.443345      6.443345      6.172174      6.140686
# X7            1.324154      1.392672      1.362448      1.324154
# X10           2.613603      3.816313      3.816313      3.925877
# X16           3.716997      3.962427      4.046752      3.962427
# X18           2.570956      2.557992      2.561768      2.560509
# ...                ...           ...           ...           ...
# X468          0.197778      0.188929      0.140019      0.188929
# X470          0.378563      0.378393      0.378284      0.378215
# X472          0.299721      0.282411      0.273176      0.268250
# X473          0.158414      0.186780      0.196876      0.158382
# X481          0.246865      0.254876      0.237830      0.255963
#
#           X2018_7_1_5h  X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  \
# meter_id
# X5            6.110991      6.008211      5.978516      6.090530
# ...

# %%
new3.to_csv("result/06_2.150_180Changed.csv")

# %%
_100_150 = pd.read_csv("result/100_150_Hrly.csv", index_col=0)
_100_150 = _100_150.set_index(_100_150.meter_id)
_100_150 = _100_150.drop(columns='meter_id')
_100_150.head(2)
# Out:
#           X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  \
# meter_id
# X166          0.459821      0.524309      0.332135      0.319993
# X472          0.206611      0.208789      0.155375      0.227641
#
#           X2018_7_1_5h  X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  \
# meter_id
# X166          0.319993      0.319993      0.319993      0.357703
# X472          0.188755      0.188755      0.279228      0.336768
#
#           X2018_7_1_9h  X2018_7_1_10h  ...  X2018_7_1_15h  X2018_7_1_16h  \
# meter_id                               ...
# X166          0.424315       0.621085  ...       0.553209       0.661634
# X472          0.311779       0.322317  ...       0.341203       0.326773
#
#           X2018_7_1_17h  X2018_7_1_18h  X2018_7_1_19h  X2018_7_1_20h  \
# meter_id
# X166           0.655991       0.654720       0.631388       0.644073
# X472           0.341955       0.373855       0.378486       0.398274
#
# ...

# %%
new4 = new3.copy()
for i in new4.index:
    if i in _100_150.index:
        for k in range(24):
            new4.loc[i][k] = _100_150.loc[i][k]
    else:
        continue
new4
# Out:
#           X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  \
# meter_id
# X5            6.443345      6.443345      6.172174      6.140686
# X7            1.324154      1.392672      1.362448      1.324154
# X10           2.613603      3.816313      3.816313      3.925877
# X16           3.716997      3.962427      4.046752      3.962427
# X18           2.570956      2.557992      2.561768      2.560509
# ...                ...           ...           ...           ...
# X468          0.197778      0.188929      0.140019      0.188929
# X470          0.291952      0.297629      0.171336      0.273549
# X472          0.206611      0.208789      0.155375      0.227641
# X473          0.158414      0.186780      0.196876      0.158382
# X481          0.246865      0.254876      0.237830      0.255963
#
#           X2018_7_1_5h  X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  \
# meter_id
# X5            6.110991      6.008211      5.978516      6.090530
# ...

# %%
new4.to_csv("result/06_3.100_150Changed.csv")

# %%
_200 = pd.read_csv("result/200_Hrly.csv", index_col=0)
_200 = _200.set_index(_200.meter_id)
_200 = _200.drop(columns='meter_id')
_200.head(2)
# Out:
#           X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  \
# meter_id
# X183          0.269685      0.260410      0.204050      0.210794
# X139          0.447930      0.468914      0.309728      0.357213
#
#           X2018_7_1_5h  X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  \
# meter_id
# X183          0.197528      0.196060      0.198927      0.221863
# X139          0.363671      0.363671      0.322827      0.363241
#
#           X2018_7_1_9h  X2018_7_1_10h  ...  X2018_7_1_15h  X2018_7_1_16h  \
# meter_id                               ...
# X183          0.215809       0.229598  ...       0.187546       0.189980
# X139          0.437172       0.477359  ...       0.463179       0.508464
#
#           X2018_7_1_17h  X2018_7_1_18h  X2018_7_1_19h  X2018_7_1_20h  \
# meter_id
# X183           0.189980       0.177045       0.188945       0.194746
# X139           0.525272       0.536259       0.587571       0.583593
#
# ...

# %%
new5 = new4.copy()
for i in new5.index:
    if i in _200.index:
        for k in range(24):
            new5.loc[i][k] = _200.loc[i][k]
    else:
        continue
new5
# Out:
#           X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  \
# meter_id
# X5            6.443345      6.443345      6.172174      6.140686
# X7            1.324154      1.392672      1.362448      1.324154
# X10           2.613603      3.816313      3.816313      3.925877
# X16           3.716997      3.962427      4.046752      3.962427
# X18           2.570956      2.557992      2.561768      2.560509
# ...                ...           ...           ...           ...
# X468          0.197778      0.188929      0.140019      0.188929
# X470          0.291952      0.297629      0.171336      0.273549
# X472          0.206611      0.208789      0.155375      0.227641
# X473          0.158414      0.186780      0.196876      0.158382
# X481          0.246865      0.254876      0.237830      0.255963
#
#           X2018_7_1_5h  X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  \
# meter_id
# X5            6.110991      6.008211      5.978516      6.090530
# ...

# %%
new5.to_csv("result/06_4. 200_allHrly_Changed.csv")

# %%
import pandas as pd

# %%
ori = pd.read_csv("result/06_4. 200_allHrly_Changed.csv", index_col=0)

# %%
daily50 = pd.read_csv("result/50_daily.csv", index_col=0)
monthly50 = pd.read_csv("result/50_Monthy.csv", index_col=0)

# %%
daily50 = daily50.set_index('meter_id')
monthly50 = monthly50.set_index('meter_id')

# %%
daily50.head()
# Out:
#           X2018_7_1_d  X2018_7_2_d  X2018_7_3_d  X2018_7_4_d  X2018_7_5_d  \
# meter_id
# X26         34.059828    33.643560    34.210125    34.059828    34.210125
# X303        13.235880    11.501531    11.501531    11.836552    12.180126
# X241         7.247790     7.075452     7.115687     7.152914     7.085038
# X435         7.129804     7.248094     7.129804     7.129804     7.248094
# X402         8.387765     8.203342     8.388251     8.203342     8.203342
#
#           X2018_7_6_d  X2018_7_7_d  X2018_7_8_d  X2018_7_9_d  X2018_7_10_d
# meter_id
# X26         34.203824    34.203824    34.203824    33.643560     34.059828
# X303        11.720967    12.825075    13.284235    11.383112     11.656555
# X241         6.894570     6.860864     7.073172     6.803696      6.719853
# X435         7.129804     7.248094     7.129804     7.248094      7.129804
# X402         8.388251     8.203342     8.203342     8.392144      8.203342

# %%
ori2 = ori.copy()
for i in ori2.index:
    if i in daily50.index:
        for k in range(10):
            ori2.loc[i][k+24] = daily50.loc[i][k]
        for j in range(5):
            ori2.loc[i][34+j] = monthly50.loc[i][j] 
    else:
        continue
ori2.to_csv("result/06_5. 50dailymonthlychanged.csv")

# %%
daily150 = pd.read_csv("result/150_daily.csv", index_col=0)
monthly150 = pd.read_csv("result/150_Monthy.csv", index_col=0)

# %%
daily150 = daily150.set_index('meter_id')
monthly150 = monthly150.set_index('meter_id')

# %%
daily150.head(2)
# Out:
#           X2018_7_1_d  X2018_7_2_d  X2018_7_3_d  X2018_7_4_d  X2018_7_5_d  \
# meter_id
# X7          33.484528    33.484528    33.145967    32.011074    33.484528
# X263         7.412015     6.630681     6.630681     6.570973     6.570973
#
#           X2018_7_6_d  X2018_7_7_d  X2018_7_8_d  X2018_7_9_d  X2018_7_10_d
# meter_id
# X7          33.484528    33.484528    32.656320    33.484528     33.484528
# X263         6.570973     7.412015     7.386919     6.605586      6.630681

# %%
monthly150.head(2)
# Out:
#             X2018_7_m    X2018_8_m   X2018_9_m   X2018_10_m  X2018_11_m
# meter_id
# X7        1009.274874  1009.274874  977.416340  1009.411754  976.908117
# X263       208.843000   202.565301  198.645237   201.308818  192.234221

# %%
ori3 = ori2.copy()
for i in ori3.index:
    if i in daily150.index:
        for k in range(10):
            ori3.loc[i][k+24] = daily150.loc[i][k]
        for j in range(5):
            ori3.loc[i][34+j] = monthly150.loc[i][j] 
    else:
        continue
ori3.head(2)
# Out:
#           X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  \
# meter_id
# X5            6.443345      6.443345      6.172174      6.140686
# X7            1.324154      1.392672      1.362448      1.324154
#
#           X2018_7_1_5h  X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  \
# meter_id
# X5            6.110991      6.008211      5.978516      6.090530
# X7            1.392672      1.368409      1.362448      1.429912
#
#           X2018_7_1_9h  X2018_7_1_10h  ...  X2018_7_6_d  X2018_7_7_d  \
# meter_id                               ...
# X5            6.016458       6.091261  ...   151.290208   150.609550
# X7            1.432966       1.432966  ...    33.484528    33.484528
#
#           X2018_7_8_d  X2018_7_9_d  X2018_7_10_d    X2018_7_m    X2018_8_m  \
# meter_id
# X5         138.224616   144.333269    144.333269  4409.067158  4407.625141
# X7          32.656320    33.484528     33.484528  1009.274874  1009.274874
#
#             X2018_9_m   X2018_10_m   X2018_11_m
# ...

# %%
ori3.to_csv("result/06_6. 150dailymonthlychanged.csv")

# %%
daily200 = pd.read_csv("result/200_daily.csv", index_col=0)
monthly200 = pd.read_csv("result/200_Monthy.csv", index_col=0)

# %%
daily200 = daily200.set_index('meter_id')
monthly200 = monthly200.set_index('meter_id')

# %%
monthly200.head()
# Out:
#            X2018_7_m   X2018_8_m   X2018_9_m  X2018_10_m  X2018_11_m
# meter_id
# X449      228.386073  228.877073  233.181016  227.280244  224.706641
# X383      166.177980  178.009153  198.759031  193.070104  171.087573
# X473      132.118967  127.038979  129.185755  150.204694  140.918276
# X205      283.795273  282.203673  265.613781  277.985827  269.742976
# X35         4.473807    4.473807    4.326593    4.470813    4.326593

# %%
ori4 = ori3.copy()
for i in ori4.index:
    if i in daily200.index:
        for k in range(10):
            ori4.loc[i][k+24] = daily200.loc[i][k]
        for j in range(5):
            ori4.loc[i][34+j] = monthly200.loc[i][j] 
    else:
        continue
ori4.tail(2)
# Out:
#           X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  \
# meter_id
# X473          0.158414      0.186780      0.196876      0.158382
# X481          0.246865      0.254876      0.237830      0.255963
#
#           X2018_7_1_5h  X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  \
# meter_id
# X473          0.158382      0.185862      0.184647      0.307352
# X481          0.253217      0.249792      0.248989      0.248115
#
#           X2018_7_1_9h  X2018_7_1_10h  ...  X2018_7_6_d  X2018_7_7_d  \
# meter_id                               ...
# X473          0.257906       0.159099  ...     4.298288     4.285180
# X481          0.248115       0.245151  ...     6.125346     6.086748
#
#           X2018_7_8_d  X2018_7_9_d  X2018_7_10_d   X2018_7_m   X2018_8_m  \
# meter_id
# X473         4.285180     4.311218      4.302956  132.118967  127.038979
# X481         6.086748     6.132979      6.099724  188.932803  188.932359
#
#            X2018_9_m  X2018_10_m  X2018_11_m
# meter_id
# ...

# %%
ori4.to_csv("result/06_7.200dailymonthlychanged.csv")

# %%
new = pd.read_csv("result/LGBMnewDaily.csv", index_col=0, sep=',')
new.head(2)
# Out:
#   meter_id  X2018_7_1d  X2018_7_2d  X2018_7_3d  X2018_7_4d  X2018_7_5d  \
# 0      X26   34.013148   31.592177   34.933560   34.794409   35.063126
# 0     X303   15.591200   12.302689    8.967595    8.890666   13.054207
#
#    X2018_7_6d  X2018_7_7d  X2018_7_8d  X2018_7_9d  X2018_7_10d
# 0   34.671373   34.680053   34.438626   31.738396    34.954131
# 0   11.649034    9.697062   17.995746    9.988300    12.593489

# %%
new =  new.set_index('meter_id')

# %%
new.head()
# Out:
#           X2018_7_1d  X2018_7_2d  X2018_7_3d  X2018_7_4d  X2018_7_5d  \
# meter_id
# X26        34.013148   31.592177   34.933560   34.794409   35.063126
# X303       15.591200   12.302689    8.967595    8.890666   13.054207
# X241        7.622918    6.511562    7.049425    6.956270    6.946787
# X435        7.322852    7.321158    7.466139    7.348576    7.439191
# X402        8.806282    8.520599    8.429880    8.443742    8.416930
#
#           X2018_7_6d  X2018_7_7d  X2018_7_8d  X2018_7_9d  X2018_7_10d
# meter_id
# X26        34.671373   34.680053   34.438626   31.738396    34.954131
# X303       11.649034    9.697062   17.995746    9.988300    12.593489
# X241        6.910282    7.102257    7.222057    6.482458     6.840060
# X435        7.123546    7.562086    7.395336    7.389308     7.181648
# X402        8.308459    8.076017    8.144674    8.487639     8.282701

# %%
ori = pd.read_csv("result/06_4. 200_allHrly_Changed.csv", index_col=0, sep=',')

# %%
ori5 = ori.copy()
for i in ori5.index:
    if i in new.index:
        for k in range(10):
            ori5.loc[i][k+24] = new.loc[i][k]
    else:
        continue

# %%
ori5.to_csv("result/06_8.200daily_new_changed.csv")

# %%
new.head()
# Out:
#           X2018_7_1d  X2018_7_2d  X2018_7_3d  X2018_7_4d  X2018_7_5d  \
# meter_id
# X26        34.013148   31.592177   34.933560   34.794409   35.063126
# X303       15.591200   12.302689    8.967595    8.890666   13.054207
# X241        7.622918    6.511562    7.049425    6.956270    6.946787
# X435        7.322852    7.321158    7.466139    7.348576    7.439191
# X402        8.806282    8.520599    8.429880    8.443742    8.416930
#
#           X2018_7_6d  X2018_7_7d  X2018_7_8d  X2018_7_9d  X2018_7_10d
# meter_id
# X26        34.671373   34.680053   34.438626   31.738396    34.954131
# X303       11.649034    9.697062   17.995746    9.988300    12.593489
# X241        6.910282    7.102257    7.222057    6.482458     6.840060
# X435        7.123546    7.562086    7.395336    7.389308     7.181648
# X402        8.308459    8.076017    8.144674    8.487639     8.282701

# %%
ori5.head(10)
# Out:
#           X2018_7_1_1h  X2018_7_1_2h  X2018_7_1_3h  X2018_7_1_4h  \
# meter_id
# X5            6.443345      6.443345      6.172174      6.140686
# X7            1.324154      1.392672      1.362448      1.324154
# X10           2.613603      3.816313      3.816313      3.925877
# X16           3.716997      3.962427      4.046752      3.962427
# X18           2.570956      2.557992      2.561768      2.560509
# X20           0.882957      0.882957      0.882957      0.242355
# X26           1.244760      1.255030      1.255030      1.255030
# X30           3.445563      2.294165      2.294165      2.294165
# X31           0.288211      0.405824      0.405472      0.407464
# X32           0.293649      0.267646      0.267775      0.267775
#
#           X2018_7_1_5h  X2018_7_1_6h  X2018_7_1_7h  X2018_7_1_8h  \
# meter_id
# X5            6.110991      6.008211      5.978516      6.090530
# X7            1.392672      1.368409      1.362448      1.429912
# ...
