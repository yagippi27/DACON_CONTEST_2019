# %%
import pandas as pd
import numpy as np
import pandas_profiling

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')

import missingno as msno
import matplotlib as mpl
import matplotlib.font_manager as fm
mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams["font.family"] = 'Malgun Gothic' 
plt.rcParams["font.size"] = 20
# %matplotlib inline

# %%
test = pd.read_csv("data/test.csv", index_col=0, sep=',')
train = pd.read_csv("data/train.csv", index_col=0, sep=',')

# %%
test.head(2)
# Out:
#                X26  X303  X241  X435  X402  X352  X305  X350  X326  X299  ...  \
# Time                                                                      ...
# 2017.7.1 0:00  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2017.7.1 1:00  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#                X283  X329  X223  X266  X20  X443  X347    X75   X107  X230
# Time
# 2017.7.1 0:00   NaN   NaN   NaN   NaN  NaN   NaN   NaN  0.275  0.021   NaN
# 2017.7.1 1:00   NaN   NaN   NaN   NaN  NaN   NaN   NaN  0.222  0.021   NaN
#
# [2 rows x 200 columns]

# %%
test.index = pd.to_datetime(test.index)

# %%
train.index = pd.to_datetime(train.index)

# %% [markdown]
# ## MissingNo 그래프

# %% [markdown]
# ### Test

# %%
msno.bar(test)
plt.title('Test data NaN분포도', fontsize=35)
# Out:
# Text(0.5, 1.0, 'Test data NaN분포도 (무작위 추출)')

# %%
msno.matrix(test, freq = 'BQS')
plt.figure(figsize = (30,30))

# %% [markdown]
# ### Train
# - 너무 칼럼이 많아 한 번에 그리면 하얗게만 보임ㅋㅋㅋ200개 가량씩 매번 나눌지 랜덤 200개 추출할지 결정 필요

# %% [markdown]
# All 1300 columns at once

# %%
msno.bar(train)

# %% [markdown]
# 랜덤 200 추출

# %%
import random as rd
rd.seed(0)
rd_cols = rd.sample(range(1300),k=200)

# %%
msno.bar(train.iloc[:, rd_cols])
plt.title('Train data NaN분포도 (무작위 추출)', fontsize=35)
# Out:
# Text(0.5, 1.0, 'Train data NaN분포도 (무작위 추출)')

# %%
msno.matrix(train.iloc[:, rd_cols], freq = 'BQS')
plt.figure(figsize = (30,30))

# %% [markdown]
# just 200칼럼씩 순차적으로

# %%
msno.bar(train.iloc[:,0:200])

# %%
msno.bar(train.iloc[:,200:400])

# %%
msno.bar(train.iloc[:,400:600])

# %%
msno.bar(train.iloc[:,600:800])

# %%
msno.bar(train.iloc[:,800:1000])

# %%
msno.bar(train.iloc[:,1000:1300])
